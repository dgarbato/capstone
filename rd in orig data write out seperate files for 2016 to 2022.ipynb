# %%
import pandas as pd
import numpy as np

# %%
from dask.distributed import Client, progress

# %%
dtypes ={'Invoice/Item Number':str,
 'Date':str,
 'Store Number':str,
 'Store Name':str,
 'Address':str,
 'City':str,
 'Zip Code':str,
 'Store Location':str,
 'County Number':str,
 'County':str,
 'Category':str,
 'Category Name':str,
 'Vendor Number':str,
 'Vendor Name':str,
 'Item Number':str,
 'Item Description':str,
 'Pack':int,
 'Bottle Volume (ml)':int,
 'State Bottle Cost':float,
 'State Bottle Retail':float,
 'Bottles Sold':int,
 'Sale (Dollars)':float,
 'Volume Sold (Liters)':float,
 'Volume Sold (Gallons)':float}

# %%
# liquor = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\Iowa_Liquor_Sales.csv',nrows=10000)

liquor_2018_df = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2018.csv', dtype = dtypes)

# %%
# liquor_2019
liquor_2019_df = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2019.csv', dtype = dtypes)

# %%
liquor_2018_df.shape
# Out:
# (2355558, 24)

# %%
pd.set_option('display.max_columns', None)
liquor_2018_df.head(2)
# Out:
#   Invoice/Item Number        Date Store Number              Store Name  \
# 0     INV-16608300016  12/28/2018         4932            B and B West
# 1     INV-16607200030  12/28/2018         5656  Cody Mart Gas & Liquor
#
#           Address         City Zip Code                Store Location  \
# 0  3105 Hudson Rd  Cedar Falls    50613  POINT (-92.465838 42.509248)
# 1  1220 N Cody Rd    Le Claire    52753   POINT (-90.34429 41.611036)
#
#   County Number      County Category    Category Name Vendor Number  \
# 0             7  BLACK HAWK  1031100  American Vodkas           300
# 1            82       SCOTT  1081600  Whiskey Liqueur           421
#
#                 Vendor Name Item Number       Item Description  Pack  \
# 0  McCormick Distilling Co.       36908    Mccormick Vodka Pet     6
# 1      SAZERAC COMPANY  INC       86881  Southern Comfort Mini    10
#
#    Bottle Volume (ml)  State Bottle Cost  State Bottle Retail  Bottles Sold  \
# ...

# %%
liquor_2019_df.shape
# Out:
# (2380345, 24)

# %%
liquor_2019_df.head()
# Out:
#   Invoice/Item Number        Date Store Number  \
# 0     INV-16840300172  01/09/2019         2621
# 1     INV-16839800075  01/09/2019         2594
# 2     INV-16678900006  01/02/2019         3651
# 3     INV-16840300157  01/09/2019         2621
# 4     INV-16839300007  01/09/2019         4655
#
#                                    Store Name               Address  \
# 0           Hy-Vee Food Store #3 / Sioux City        3301 Gordon Dr
# 1              Hy-Vee Food Store / Sioux City    4500 Sergeant Road
# 2                   Wal-Mart 1491 / Indianola  1500 North Jefferson
# 3           Hy-Vee Food Store #3 / Sioux City        3301 Gordon Dr
# 4  Casey's General Store #2237 / Prairie City         1002 W 2nd St
#
#            City Zip Code                Store Location County Number  \
# 0    Sioux City    51105  POINT (-96.364108 42.487752)            97
# 1    Sioux City    51106  POINT (-96.346969 42.447396)            97
# ...

# %%
liquor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Invoice/Item Number    10000 non-null  object
#  1   Date                   10000 non-null  object
#  2   Store Number           10000 non-null  int64
#  3   Store Name             10000 non-null  object
#  4   Address                10000 non-null  object
#  5   City                   10000 non-null  object
#  6   Zip Code               10000 non-null  object
#  7   Store Location         9084 non-null   object
#  8   County Number          9535 non-null   float64
#  9   County                 9535 non-null   object
#  10  Category               10000 non-null  int64
#  11  Category Name          9999 non-null   object
#  12  Vendor Number          10000 non-null  int64
#  13  Vendor Name            10000 non-null  object
# ...

# %%
# import csv

# def getstuff(filename):
#     with open(filename, "r") as csvfile:
#         datareader = csv.reader(csvfile)
#         yield next(datareader)  # yield the header row
#         count = 0
#         for row in datareader:
#             if row[1][6:] in ['2017','2018','2019','2020','2021']:
#                 yield row
#                 count += 1
#             elif count:
#                 # done when having read a consecutive series of rows 
#                 return

# %% [markdown]
# function to read in certain years only

# %%
import csv
def getstuff2(filename, years):
    dict1={}
    with open(filename, "r") as csvfile:
        datareader = csv.reader(csvfile)
        dict1['header'] = next(datareader)  # the header row
        count = 0
        rows = []
        for row in datareader:
#             if row[2][-4:] in years:
            if row[1][-4:] in years:
                rows.append(row)
                count += 1
                if count % 1000 == 0:
                    print(row[1][-4:])
           
        dict1['rows'] = rows
        
        print(count)
                # done when having read a consecutive series of rows 
        return dict1

# %%
# liquor_2021_2022['Date']

# %%
file = r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\Iowa_Liquor_Sales.csv'

# %%
# '2017','2018','2019','2020','2021', '2022'

# %%
years = ['2016']
liquor_2019 = getstuff2(file,years)
# Out:
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# ...

# %%
years = ['2019']
liquor_2019 = getstuff2(file,years)
# Out:
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# ...

# %%
# years =['2022']
# liquor_2022 = getstuff2(file,years)

# %%
years =['2017']
liquor_2017 = getstuff2(file,years)
# Out:
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# ...

# %%
years =['2021']
liquor_2021 = getstuff2(file,years)
# Out:
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# ...

# %%
years =['2020']
liquor_2020 = getstuff2(file,years)
# Out:
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# ...

# %%
liquor_2022['header']
# Out:
# ['Invoice/Item Number',
#  'Date',
#  'Store Number',
#  'Store Name',
#  'Address',
#  'City',
#  'Zip Code',
#  'Store Location',
#  'County Number',
#  'County',
#  'Category',
#  'Category Name',
#  'Vendor Number',
#  'Vendor Name',
#  'Item Number',
#  'Item Description',
#  'Pack',
#  'Bottle Volume (ml)',
#  'State Bottle Cost',
#  'State Bottle Retail',
#  'Bottles Sold',
#  'Sale (Dollars)',
#  'Volume Sold (Liters)',
#  'Volume Sold (Gallons)']

# %%
liquor_2021['rows']
# Out:
# [['INV-41517100002',
#   '11/01/2021',
#   '5417',
#   "Casey's General Store # 2792/Cedar Rapids",
#   '9001 6th Street SW',
#   'Cedar Rapids',
#   '52404',
#   '',
#   '57',
#   'LINN',
#   '1031100',
#   'American Vodkas',
#   '434',
#   'LUXCO INC',
#   '36308',
#   'Hawkeye Vodka',
#   '6',
#   '1750',
#   '7.17',
#   '10.76',
#   '6',
#   '64.56',
#   '10.50',
#   '2.77'],
#  ['INV-41518800037',
#   '11/01/2021',
#   '4921',
#   'Market Express',
#   '5340 16th Ave SW',
#   'Cedar Rapids',
#   '52404',
#   '',
#   '57',
#   'LINN',
#   '1011200',
#   'Straight Bourbon Whiskies',
#   '065',
#   'Jim Beam Brands',
#   '19061',
#   'Jim Beam Mini',
#   '12',
#   '50',
#   '7.00',
#   '10.50',
#   '1',
#   '10.50',
#   '0.05',
#   '0.01'],
#  ['INV-41518900014',
#   '11/01/2021',
#   '5687',
#   "Casey's General Store #3756 / Cedar Rapids",
#   '4560 16th Ave SW',
#   'Cedar Rapids',
#   '52404',
#   '',
#   '57',
#   'LINN',
#   '1012100',
#   'Canadian Whiskies',
#   '260',
# ...

# %% [markdown]
# function to write out data

# %%
def write(filename,dict1):
    with open(filename, 'w', newline="") as file:
        csvwriter = csv.writer(file) # 2. create a csvwriter object
        csvwriter.writerow(dict1['header']) # 4. write the header
        csvwriter.writerows(dict1['rows']) # 5. write the rest of the data

# %%
filename = r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2016.csv'
write(filename,liquor_2019 )  #data is actually 2016

# %%
filename = r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2018.csv'
write(filename,liquor_2021) #data is actually 2018

# %%
filename = r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2019.csv'
write(filename,liquor_2019) #data is  2019

# %%
# liquor_2022
filename = r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2022.csv'
write(filename,liquor_2022) #data is  liquor_2022

# %%
# liquor_2020
filename = r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2020.csv'
write(filename,liquor_2020) #data is  liquor_2020

# %%
# liquor_2021

filename = r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2021.csv'
write(filename,liquor_2021) #data is actually liquor_2021

# %%
# liquor_2017

filename = r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2017.csv'
write(filename,liquor_2017) #data is  liquor_2017

# %%
pd.set_option('display.max_columns', None)
liquor.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0        S32100500009  05/03/2016          4311
# 1        S32072000024  05/02/2016          4114
# 2        S32021800012  04/27/2016          2622
# 3        S32094100014  05/04/2016          4745
# 4        S32037400007  04/28/2016          4959
#
#                          Store Name                  Address          City  \
# 0  Fareway Stores #508 / Fort Dodge          1231  1st Ave S    Fort Dodge
# 1                 After 5 Somewhere  704 W 7th St Po Box 372      Atlantic
# 2     Hy-Vee Food Store / Iowa City          1125 N DODGE ST     IOWA CITY
# 3   Walgreens #05042 / Cedar Rapids         3325 16th Ave SW  Cedar Rapids
# 4                            Bani's          2128 COLLEGE ST   CEDAR FALLS
#
#   Zip Code                         Store Location  County Number      County  \
# 0    50501             POINT (-94.18154 42.50513)           94.0     Webster
# ...

# %%
products = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\Iowa_Liquor_Products.csv')

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10443 entries, 0 to 10442
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Item Number          10443 non-null  object
#  1   Category Name        10443 non-null  object
#  2   Item Description     10443 non-null  object
#  3   Vendor               10443 non-null  int64
#  4   Vendor Name          10443 non-null  object
#  5   Bottle Volume (ml)   10443 non-null  int64
#  6   Pack                 10443 non-null  int64
#  7   Inner Pack           10443 non-null  int64
#  8   Age                  10443 non-null  int64
#  9   Proof                10443 non-null  int64
#  10  List Date            10443 non-null  object
#  11  UPC                  10442 non-null  float64
#  12  SCC                  10443 non-null  int64
#  13  State Bottle Cost    10443 non-null  float64
#  14  State Case Cost      10443 non-null  float64
# ...

# %%
pd.set_option('display.max_columns', None)

products.head(5)
# Out:
#   Item Number                 Category Name  \
# 0      901141           Special Order Items
# 1       65017  Imported Cordials & Liqueurs
# 2       88152            100% Agave Tequila
# 3      903796           Special Order Items
# 4      905846               Scotch Whiskies
#
#                            Item Description  Vendor  \
# 0  Libertine Absinthe(French Absinthe) Mini     885
# 1                          Galliano Liqueur     305
# 2                          Sauza 901 Silver      65
# 3                       Bacardi Anejo DISCO      35
# 4                              Ron Burgundy     305
#
#                  Vendor Name  Bottle Volume (ml)  Pack  Inner Pack  Age  \
# 0  YAHARA BAY DISTILLERS INC                  50     6           1    0
# 1                    Mhw LTD                 375    12           1    0
# 2            Jim Beam Brands                 750     6           1    0
# 3            BACARDI USA INC                 750    12           1    0
# ...

# %%
products.shape
# Out:
# (10443, 17)

# %%
def proc_freq(df,variable_):  #Note variable_ must be given in quotes example: variable_ = 'xyz'
    datax = df[variable_].value_counts().sort_index()
    
    datay = pd.DataFrame({
        variable_: datax.index,
        'Frequency': datax.values,
        'Percent': ((datax.values/datax.values.sum())*100).round(2),
        'Cumulative_Frequency': datax.values.cumsum(),
        'Cumulative_Percent': ((datax.values.cumsum()/datax.values.sum())*100).round(2)   })
    
    #datay.set_index(variable_)
    #return(datay.set_index(variable_))
    return(datay)

# %%
print(products['Category Name'].value_counts().to_string())
# Out:
# Special Order Items                     1209
# Temporary & Specialty Packages          1144
# Straight Bourbon Whiskies                640
# 100% Agave Tequila                       573
# American Flavored Vodka                  566
# Blended Whiskies                         387
# Single Malt Scotch                       357
# American Vodkas                          353
# Imported Flavored Vodka                  274
# Scotch Whiskies                          264
# Cocktails /RTD                           259
# Canadian Whiskies                        243
# Flavored Rum                             238
# American Cordials & Liqueur              235
# Straight Rye Whiskies                    201
# Imported Brandies                        194
# Imported Cordials & Liqueur              183
# Irish Whiskies                           178
# Imported Vodkas                          160
# American Schnapps                        159
# American Dry Gins                        158
# ...

# %%
print(proc_freq(products,'Category Name').to_string())
# Out:
#                            Category Name  Frequency  Percent  Cumulative_Frequency  Cumulative_Percent
# 0                     100% Agave Tequila        573     5.49                   573                5.49
# 1                          Aged Dark Rum        146     1.40                   719                6.88
# 2                      American Brandies        140     1.34                   859                8.23
# 3                        American Brandy          2     0.02                   861                8.24
# 4            American Cordials & Liqueur        235     2.25                  1096               10.50
# 5           American Cordials & Liqueurs         45     0.43                  1141               10.93
# 6    American Distilled Spirit Specialty        102     0.98                  1243               11.90
# 7   American Distilled Spirits Specialty         25     0.24                  1268               12.14
# ...

# %%
print(proc_freq(products,'Vendor Name').to_string())
# Out:
#                                                              Vendor Name  Frequency  Percent  Cumulative_Frequency  Cumulative_Percent
# 0                                 10th Mountain Whiskey & Spirit Company          1     0.01                     1                0.01
# 1                                                           2bar Spirits          1     0.01                     2                0.02
# 2                                                    3 BADGE CORPORATION         25     0.24                    27                0.26
# 3                                                 3-Oaks Distillery, LLC          2     0.02                    29                0.28
# 4                                                  45TH PARALLEL SPIRITS         10     0.10                    39                0.37
# 5                                                        A HARDY USA LTD          2     0.02                    41                0.39
# ...
