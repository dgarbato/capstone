# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
from freq_pd import proc_freq

# %%
prod_clusters = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2021\product_clusters.csv',dtype={'Item_Number':str}, index_col=0)

# %%
pdtypes = {'Item Number':str,'Vendor':str}

# %%
products_iowa = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\Iowa_Liquor_Products(1).csv',dtype=pdtypes)

# %%
# products_iowa.rename({'Item Description':'Item_Description'} ,axis=1, inplace=True)

# %%
products_iowa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10568 entries, 0 to 10567
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Item Number          10568 non-null  object
#  1   Category Name        10568 non-null  object
#  2   Item Description     10568 non-null  object
#  3   Vendor               10568 non-null  object
#  4   Vendor Name          10568 non-null  object
#  5   Bottle Volume (ml)   10568 non-null  int64
#  6   Pack                 10568 non-null  int64
#  7   Inner Pack           10568 non-null  int64
#  8   Age                  10568 non-null  int64
#  9   Proof                10568 non-null  int64
#  10  List Date            10568 non-null  object
#  11  UPC                  10567 non-null  float64
#  12  SCC                  10568 non-null  int64
#  13  State Bottle Cost    10568 non-null  float64
#  14  State Case Cost      10568 non-null  float64
#  15  State Bottle Retail  10568 non-null  float64
#  16  Report Date          10568 non-null  object
# dtypes: float64(4), int64(6), object(7)
# memory usage: 1.4+ MB

# %%
products_iowa.head()
# Out:
#   Item Number                 Category Name  \
# 0      901141           Special Order Items
# 1       65017  Imported Cordials & Liqueurs
# 2       88152            100% Agave Tequila
# 3      903796           Special Order Items
# 4      905846               Scotch Whiskies
#
#                            Item Description Vendor                Vendor Name  \
# 0  Libertine Absinthe(French Absinthe) Mini    885  YAHARA BAY DISTILLERS INC
# 1                          Galliano Liqueur    305                    Mhw LTD
# 2                          Sauza 901 Silver    065            Jim Beam Brands
# 3                       Bacardi Anejo DISCO    035            BACARDI USA INC
# 4                              Ron Burgundy    305                    Mhw LTD
#
#    Bottle Volume (ml)  Pack  Inner Pack  Age  Proof   List Date           UPC  \
# 0                  50     6           1    0    114  04/20/2012           NaN
# 1                 375    12           1    0     84  10/01/2012  8.091511e+10
# 2                 750     6           1    0     80  06/01/2014  8.068684e+10
# 3                 750    12           1    0     80  09/01/1990  8.068684e+10
# 4                 750    12           1    0     80  10/01/2014  8.068684e+10
#
#               SCC  State Bottle Cost  State Case Cost  State Bottle Retail  \
# 0  10892060104050               4.82            28.90                 7.23
# 1  10892060104050              10.75           129.00                16.13
# 2  10892060104050              13.12            78.72                19.68
# 3     80480004347               7.75            93.00                11.63
# 4  10626990143885              14.61           175.25                21.92
#
#   Report Date
# 0  04/01/2022
# 1  04/01/2022
# 2  04/01/2022
# 3  04/01/2022
# 4  04/01/2022

# %%
products_iowa.drop(columns=['UPC','SCC',])
# Out:
#       Item Number                   Category Name  \
# 0          901141             Special Order Items
# 1           65017    Imported Cordials & Liqueurs
# 2           88152              100% Agave Tequila
# 3          903796             Special Order Items
# 4          905846                 Scotch Whiskies
# ...           ...                             ...
# 10563       86285  Temporary & Specialty Packages
# 10564      978195       Straight Bourbon Whiskies
# 10565       76407  Neutral Grain Spirits Flavored
# 10566       76409  Neutral Grain Spirits Flavored
# 10567       15548  Temporary & Specialty Packages
#
#                                Item Description Vendor  \
# 0      Libertine Absinthe(French Absinthe) Mini    885
# 1                              Galliano Liqueur    305
# 2                              Sauza 901 Silver    065
# 3                           Bacardi Anejo DISCO    035
# 4                                  Ron Burgundy    305
# ...                                         ...    ...
# 10563          El Mayor Extra Anejo Port Finish    434
# 10564      Gold Bar Black Bourbon Double Casked    368
# 10565            Ole Smoky Sour Apple Moonshine    346
# 10566       Ole Smoky Sour Watermelon Moonshine    346
# 10567      Drumshanbo Single Malt Irish Whiskey    357
#
#                      Vendor Name  Bottle Volume (ml)  Pack  Inner Pack  Age  \
# 0      YAHARA BAY DISTILLERS INC                  50     6           1    0
# 1                        Mhw LTD                 375    12           1    0
# 2                Jim Beam Brands                 750     6           1    0
# 3                BACARDI USA INC                 750    12           1    0
# 4                        Mhw LTD                 750    12           1    0
# ...                          ...                 ...   ...         ...  ...
# 10563                  LUXCO INC                 750     3           1    0
# 10564        Park Street Imports                 750     6           1    0
# 10565   OLE SMOKY DISTILLERY LLC                 750     6           1    0
# 10566   OLE SMOKY DISTILLERY LLC                 750     6           1    0
# 10567     PALM BAY INTERNATIONAL                 700     6           1    0
#
#        Proof   List Date  State Bottle Cost  State Case Cost  \
# 0        114  04/20/2012               4.82            28.90
# 1         84  10/01/2012              10.75           129.00
# 2         80  06/01/2014              13.12            78.72
# 3         80  09/01/1990               7.75            93.00
# 4         80  10/01/2014              14.61           175.25
# ...      ...         ...                ...              ...
# 10563     80  05/01/2022              62.50           187.50
# 10564     92  05/01/2022              27.67           166.02
# 10565     40  05/01/2022              12.50            75.00
# 10566     40  05/01/2022              12.50            75.00
# 10567     92  05/01/2022              55.00           330.00
#
#        State Bottle Retail Report Date
# 0                     7.23  04/01/2022
# 1                    16.13  04/01/2022
# 2                    19.68  04/01/2022
# 3                    11.63  04/01/2022
# 4                    21.92  04/01/2022
# ...                    ...         ...
# 10563                93.75  04/01/2022
# 10564                41.51  04/01/2022
# 10565                18.75  04/01/2022
# 10566                18.75  04/01/2022
# 10567                82.50  04/01/2022
#
# [10568 rows x 15 columns]

# %%
# proc_freq(products_iowa,'Age') 96% have age zero

# %%
# item_trans_category = item_trans_category.merge(products, how='inner', on=['Item_Number','Category'])

# %%
# prod_clusters_iowa = prod_clusters.merge(products_iowa, how='inner',on=['Item Description'])

# %%
prod_clusters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4304 entries, 1 to 4474
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Item_Number         4304 non-null   object
#  1   Item_Description    4304 non-null   object
#  2   Bottle_Volume       4304 non-null   int64
#  3   Bottle_Retail       4304 non-null   float64
#  4   Bottles_Sold        4304 non-null   int64
#  5   cluster_name        4304 non-null   object
#  6   revenue             4304 non-null   float64
#  7   Num_Stores_Selling  4304 non-null   int64
#  8   New_Category_Name   4304 non-null   object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 336.2+ KB

# %%
prod_clusters.describe()
# Out:
#        Bottle_Volume  Bottle_Retail   Bottles_Sold       revenue  \
# count    4304.000000    4304.000000    4304.000000  4.304000e+03
# mean      817.151022      28.607939    6599.188197  9.553405e+04
# std       379.863360      32.255328   24778.767211  3.926987e+05
# min        20.000000       0.990000       1.000000  7.500000e+00
# 25%       750.000000      11.389293      55.000000  1.428465e+03
# 50%       750.000000      20.185164     575.000000  1.325902e+04
# 75%       750.000000      34.140774    3729.500000  5.347715e+04
# max      2400.000000     495.750000  563260.000000  1.062280e+07
#
#        Num_Stores_Selling
# count         4304.000000
# mean           122.778113
# std            209.079123
# min              1.000000
# 25%              3.000000
# 50%             49.000000
# 75%            152.000000
# max           1725.000000

# %%
everything_else = prod_clusters.loc[prod_clusters['cluster_name']=='Everything_Else',:]

# %%
everything_else.head(10)
# Out:
#    Item_Number                                Item_Description  Bottle_Volume  \
# 1        10006                            Scoresby Rare Scotch            750
# 2       100077                        Kraken Rum w/ Tiki Glass            750
# 4        10009                            Scoresby Rare Scotch           1000
# 5       100148      Jack Daniels Single Barrel w/Snifter Glass            750
# 6       100202  Baileys Original Irish Cream w/2 Dessert Bowls            750
# 7       100210                             Clyde Mays Dualpack            750
# 8       100215           Tequila Rose Liqueur w/2 Shot Glasses            750
# 9       100216         Tarantula Azul Holiday w/2 Shot Glasses            750
# 10      100248                 Martell Blue Swift w/ 2 Glasses            750
# 11      100280              The Bitter Truth Cocktail Bar Pack             20
#
#     Bottle_Retail  Bottles_Sold     cluster_name   revenue  \
# 1            7.70          4619  Everything_Else  35566.30
# 2           15.68          2679  Everything_Else  42006.72
# 4           10.11          1722  Everything_Else  17409.42
# 5           41.39           606  Everything_Else  25082.34
# 6           24.74          3160  Everything_Else  78178.40
# 7           30.00            66  Everything_Else   1980.00
# 8           17.25          1191  Everything_Else  20544.75
# 9           13.49           133  Everything_Else   1794.17
# 10          31.47            47  Everything_Else   1479.09
# 11          14.25           180  Everything_Else   2565.00
#
#     Num_Stores_Selling               New_Category_Name
# 1                  197                          Scotch
# 2                  136  Temporary & Specialty Packages
# 4                   70                          Scotch
# 5                  120  Temporary & Specialty Packages
# 6                  149  Temporary & Specialty Packages
# 7                    1  Temporary & Specialty Packages
# 8                  161  Temporary & Specialty Packages
# 9                   24  Temporary & Specialty Packages
# 10                   8  Temporary & Specialty Packages
# 11                  38                       Cocktails

# %%
scaler = StandardScaler()

# %%
everything_else[['Bottle_Volume_scaled', 'Bottle_Retail_scaled', 'Bottles_Sold_scaled' ]] = scaler.fit_transform\
                                           (everything_else[['Bottle_Volume', 'Bottle_Retail', 'Bottles_Sold']])
                                                   

everything_else[['Bottle_Volume_scaled', 'Bottle_Retail_scaled', 'Bottles_Sold_scaled']].describe()
# Out:
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
#        Bottle_Volume_scaled  Bottle_Retail_scaled  Bottles_Sold_scaled
# count          3.651000e+03          3.651000e+03         3.651000e+03
# mean           4.440284e-16          5.136036e-16        -7.312997e-16
# std            1.000137e+00          1.000137e+00         1.000137e+00
# min           -3.248683e+00         -1.361810e+00        -3.929446e-01
# 25%            2.151304e-01         -7.617697e-01        -3.883847e-01
# 50%            2.151304e-01         -2.597378e-01        -3.464515e-01
# 75%            2.151304e-01          4.979734e-01        -9.306393e-02
# max            2.350358e+00          3.668852e+00         8.325679e+00

# %% [markdown]
# determine optimal number of clusters

# %%
from sklearn.metrics import silhouette_score

cluster_cols = ['Bottle_Volume_scaled', 'Bottle_Retail_scaled', 'Bottles_Sold_scaled' ]

df_scaled = everything_else[cluster_cols]


for clust in range(2,11):
    model = KMeans(n_clusters=clust, random_state=42).fit(df_scaled)
    

    
    silhouette_avg = silhouette_score(df_scaled,model.labels_)
    print('number of clusters = ',clust,' ','silhouette score = ',silhouette_avg)
# Out:
# number of clusters =  2   silhouette score =  0.5753314073274531
# number of clusters =  3   silhouette score =  0.5738019793962222
# number of clusters =  4   silhouette score =  0.5127222521695394
# number of clusters =  5   silhouette score =  0.42088976593822036
# number of clusters =  6   silhouette score =  0.44630719576083355
# number of clusters =  7   silhouette score =  0.48800770163811
# number of clusters =  8   silhouette score =  0.4931659382631954
# number of clusters =  9   silhouette score =  0.4628871540550925
# number of clusters =  10   silhouette score =  0.4633959187905847

# %%
inertia_scores = []

for clust in range(2,11):
    inertia = KMeans(n_clusters=clust, random_state=42)\
              .fit(df_scaled).inertia_
    inertia_scores.append(inertia)

# %%
plt.plot(range(2,11), inertia_scores)
plt.title("Inertia vs. number of clusters")
plt.xlabel("Number of clusters: K")
plt.ylabel('Inertia')
plt.show()

# %%
# stop

# %% [markdown]
# get three sub-clusters from everything_else

# %%
cluster_cols = ['Bottle_Volume_scaled', 'Bottle_Retail_scaled', 'Bottles_Sold_scaled' ]


model = KMeans(n_clusters=4, random_state=42)

model.fit(everything_else[cluster_cols])

everything_else['sub_cluster'] = model.predict(everything_else[cluster_cols])
# Out:
# C:\Users\dgarb\AppData\Local\Temp/ipykernel_28288/3938904934.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   everything_else['sub_cluster'] = model.predict(everything_else[cluster_cols])

# %%
everything_else.head()
# Out:
#   Item_Number                                Item_Description  Bottle_Volume  \
# 1       10006                            Scoresby Rare Scotch            750
# 2      100077                        Kraken Rum w/ Tiki Glass            750
# 4       10009                            Scoresby Rare Scotch           1000
# 5      100148      Jack Daniels Single Barrel w/Snifter Glass            750
# 6      100202  Baileys Original Irish Cream w/2 Dessert Bowls            750
#
#    Bottle_Retail  Bottles_Sold     cluster_name   revenue  Num_Stores_Selling  \
# 1           7.70          4619  Everything_Else  35566.30                 197
# 2          15.68          2679  Everything_Else  42006.72                 136
# 4          10.11          1722  Everything_Else  17409.42                  70
# 5          41.39           606  Everything_Else  25082.34                 120
# 6          24.74          3160  Everything_Else  78178.40                 149
#
#                 New_Category_Name  Bottle_Volume_scaled  Bottle_Retail_scaled  \
# 1                          Scotch              0.215130             -0.967835
# 2  Temporary & Specialty Packages              0.215130             -0.499293
# 4                          Scotch              1.401368             -0.826333
# 5  Temporary & Specialty Packages              0.215130              1.010258
# 6  Temporary & Specialty Packages              0.215130              0.032661
#
#    Bottles_Sold_scaled  sub_cluster
# 1             0.019950            0
# 2            -0.153505            0
# 4            -0.239070            0
# 5            -0.338852            3
# 6            -0.110499            0

# %%
everything_else['Bottle_Volume_liters'] = everything_else['Bottle_Volume']/1000
# Out:
# C:\Users\dgarb\AppData\Local\Temp/ipykernel_28288/2100188245.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   everything_else['Bottle_Volume_liters'] = everything_else['Bottle_Volume']/1000

# %% [markdown]
# # create price per milliliter

# %%
# price/volume
everything_else['price_per_ml'] = everything_else['Bottle_Retail'] / everything_else['Bottle_Volume']
# Out:
# C:\Users\dgarb\AppData\Local\Temp/ipykernel_28288/1856010719.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   everything_else['price_per_ml'] = everything_else['Bottle_Retail'] / everything_else['Bottle_Volume']

# %%
everything_else.groupby(['sub_cluster']).agg({'Bottle_Volume_liters' : 'mean', 'Bottle_Retail':'mean','Bottles_Sold':'mean' })
# Out:
#              Bottle_Volume_liters  Bottle_Retail  Bottles_Sold
# sub_cluster
# 0                        0.785045      17.943764   2843.421364
# 1                        0.210961       8.983089   4851.725400
# 2                        0.661213      12.766997  52484.845588
# 3                        0.755698      49.153333    610.076310

# %%
everything_else.groupby(['sub_cluster']).agg({'Bottle_Volume' :['min','max','std', 'median', 'mean'], 'Bottle_Retail':['min','max','std', 'median', 'mean'],'Bottles_Sold':['min','max','std', 'median', 'mean'] })
# Out:
#             Bottle_Volume                                      Bottle_Retail  \
#                       min   max         std median        mean           min
# sub_cluster
# 0                     750  1000   86.248674  750.0  785.045455          3.20
# 1                      20   400  142.691175  200.0  210.961098          0.99
# 2                      50  1000  293.112604  750.0  661.213235          1.43
# 3                     375  1200   48.399127  750.0  755.698178         33.24
#
#                                                     Bottles_Sold         \
#                   max        std  median       mean          min    max
# sub_cluster
# 0            37.13645   7.737670  17.245  17.943764            1  29833
# 1            37.50000   6.128577   7.500   8.983089            2  37385
# 2            37.47000   8.486749  11.250  12.766997        28404  97514
# 3            86.67000  13.057423  45.000  49.153333            1  26065
#
#
#                       std   median          mean
# sub_cluster
# 0             4702.926358    775.5   2843.421364
# 1             6819.117730   2162.0   4851.725400
# 2            19746.505651  47580.5  52484.845588
# 3             1747.022821     78.5    610.076310

# %%
from freq_pd import proc_freq

# %%
proc_freq(everything_else,'sub_cluster')
# Out:
#    sub_cluster  Frequency  Percent  Cumulative_Frequency  Cumulative_Percent
# 0            0       2200    60.26                  2200               60.26
# 1            1        437    11.97                  2637               72.23
# 2            2        136     3.73                  2773               75.95
# 3            3        878    24.05                  3651              100.00

# %%
everything_else['str_volume'] = str(everything_else.Bottle_Volume)
# Out:
# C:\Users\dgarb\AppData\Local\Temp/ipykernel_28288/1745242950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   everything_else['str_volume'] = str(everything_else.Bottle_Volume)

# %%
df = everything_else.groupby(['sub_cluster']).agg({'revenue':'sum'})
df.style.format("{:.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6edf8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >revenue</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sub_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6edf8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6edf8_row0_col0" class="data row0 col0" >93721889</td>
#     </tr>
#     <tr>
#       <th id="T_6edf8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6edf8_row1_col0" class="data row1 col0" >14863536</td>
#     </tr>
#     <tr>
#       <th id="T_6edf8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6edf8_row2_col0" class="data row2 col0" >89864386</td>
#     </tr>
#     <tr>
#       <th id="T_6edf8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6edf8_row3_col0" class="data row3 col0" >23972997</td>
#     </tr>
#   </tbody>
# </table>

# %%
everything_else.groupby(['sub_cluster']).agg({'Bottle_Volume':'nunique'})
# Out:
#              Bottle_Volume
# sub_cluster
# 0                        6
# 1                        8
# 2                        6
# 3                        8

# %%
everything_else.groupby(['sub_cluster']).agg({'Item_Number':['nunique'],'revenue':['sum'],'Bottle_Volume':['nunique','min','max','std', 'median', 'mean'],'Bottle_Retail':['min','max','std', 'median', 'mean'], 'price_per_ml':['min','max','std', 'median', 'mean'],'Bottles_Sold':['sum','min','max','std', 'median', 'mean'] })
# Out:
#             Item_Number      revenue Bottle_Volume                         \
#                 nunique          sum       nunique  min   max         std
# sub_cluster
# 0                  2200  93721888.64             6  750  1000   86.248674
# 1                   437  14863536.11             8   20   400  142.691175
# 2                   136  89864385.55             6   50  1000  293.112604
# 3                   877  23972997.01             8  375  1200   48.399127
#
#                                Bottle_Retail                               \
#             median        mean           min       max        std  median
# sub_cluster
# 0            750.0  785.045455          3.20  37.13645   7.737670  17.245
# 1            200.0  210.961098          0.99  37.50000   6.128577   7.500
# 2            750.0  661.213235          1.43  37.47000   8.486749  11.250
# 3            750.0  755.698178         33.24  86.67000  13.057423  45.000
#
#                        price_per_ml                                         \
#                   mean          min       max       std   median      mean
# sub_cluster
# 0            17.943764      0.00320  0.045507  0.010435  0.02200  0.023254
# 1             8.983089      0.00688  0.712500  0.072077  0.03750  0.075992
# 2            12.766997      0.00350  0.144000  0.018753  0.01806  0.022293
# 3            49.153333      0.03575  0.226896  0.018750  0.06000  0.065398
#
#             Bottles_Sold
#                      sum    min    max           std   median          mean
# sub_cluster
# 0                6255527      1  29833   4702.926358    775.5   2843.421364
# 1                2120204      2  37385   6819.117730   2162.0   4851.725400
# 2                7137939  28404  97514  19746.505651  47580.5  52484.845588
# 3                 535647      1  26065   1747.022821     78.5    610.076310

# %%
everything_else.groupby(['sub_cluster']).agg({'Num_Stores_Selling':['min','max','std', 'median', 'mean']})
# Out:
#             Num_Stores_Selling
#                            min   max         std median        mean
# sub_cluster
# 0                            1   932  125.452913   50.0   97.159545
# 1                            1  1069  167.786271   97.0  145.322654
# 2                           25  1551  392.496251  518.5  649.764706
# 3                            1   660   76.920792    6.0   46.389522

# %%
pd.set_option('display.max_columns', None)
everything_else.groupby(['sub_cluster']).agg({'Item_Number':['nunique'],'revenue':['sum'],'Bottle_Volume':['nunique','min','max','std','median'],'price_per_ml':['min','max','std', 'median', 'mean'],'Bottles_Sold':['sum','min','max','std', 'median', 'mean'],'Num_Stores_Selling':['min','max','std', 'median', 'mean'] })
# Out:
#             Item_Number      revenue Bottle_Volume                         \
#                 nunique          sum       nunique  min   max         std
# sub_cluster
# 0                  2200  93721888.64             6  750  1000   86.248674
# 1                   437  14863536.11             8   20   400  142.691175
# 2                   136  89864385.55             6   50  1000  293.112604
# 3                   877  23972997.01             8  375  1200   48.399127
#
#                    price_per_ml                                         \
#             median          min       max       std   median      mean
# sub_cluster
# 0            750.0      0.00320  0.045507  0.010435  0.02200  0.023254
# 1            200.0      0.00688  0.712500  0.072077  0.03750  0.075992
# 2            750.0      0.00350  0.144000  0.018753  0.01806  0.022293
# 3            750.0      0.03575  0.226896  0.018750  0.06000  0.065398
#
#             Bottles_Sold                                                     \
#                      sum    min    max           std   median          mean
# sub_cluster
# 0                6255527      1  29833   4702.926358    775.5   2843.421364
# 1                2120204      2  37385   6819.117730   2162.0   4851.725400
# 2                7137939  28404  97514  19746.505651  47580.5  52484.845588
# 3                 535647      1  26065   1747.022821     78.5    610.076310
#
#             Num_Stores_Selling
#                            min   max         std median        mean
# sub_cluster
# 0                            1   932  125.452913   50.0   97.159545
# 1                            1  1069  167.786271   97.0  145.322654
# 2                           25  1551  392.496251  518.5  649.764706
# 3                            1   660   76.920792    6.0   46.389522

# %%
everything_else['str_volume'] = [str(prod) for prod in everything_else.Bottle_Volume ]
# [str(prod) for prod in everything_else.Bottle_Volume ]
# Out:
# C:\Users\dgarb\AppData\Local\Temp/ipykernel_28288/3195886119.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   everything_else['str_volume'] = [str(prod) for prod in everything_else.Bottle_Volume ]

# %%
# stop

# %% [markdown]
# # Name sub-clusters

# %%
sub_clust_dict ={0:'Most_Variety', 1:'Quick_Shots', 2:'Cheap', 3:'Moderately_High'}
# {0:'Most_Variety', 1:'Quick_Shots', 2:'Cheap', 3:'Moderately_High'}

everything_else['sub_cluster'].map(sub_clust_dict)
# Out:
# 1          Most_Variety
# 2          Most_Variety
# 4          Most_Variety
# 5       Moderately_High
# 6          Most_Variety
#              ...
# 4470    Moderately_High
# 4471    Moderately_High
# 4472    Moderately_High
# 4473    Moderately_High
# 4474        Quick_Shots
# Name: sub_cluster, Length: 3651, dtype: object

# %%
everything_else['sub_cluster_name'] = everything_else['sub_cluster'].map(sub_clust_dict)
# Out:
# C:\Users\dgarb\AppData\Local\Temp/ipykernel_28288/3136741811.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   everything_else['sub_cluster_name'] = everything_else['sub_cluster'].map(sub_clust_dict)

# %%
# df_categ = everything_else.groupby(['sub_cluster','New_Category_Name']).agg({'price_per_ml':['min','max','std', 'median', 'mean']}).reset_index()

# %%
# df_categ.loc[df_categ.sub_cluster==2,:]

# %%
Moderately_High = everything_else.loc[everything_else['sub_cluster_name']== 'Moderately_High',['Item_Number', 'Item_Description','revenue','Bottle_Retail','Bottle_Volume','Bottles_Sold']]

# %%
Moderately_High
# Out:
#      Item_Number                            Item_Description   revenue  \
# 5         100148  Jack Daniels Single Barrel w/Snifter Glass  25082.34
# 12        100306                          Patron Extra Anejo  30451.68
# 21        100600           Woodford Reserve w/Mint Julep Cup  19029.36
# 25        100618        Crystal Head Vodka w/4 Skull Glasses   5998.40
# 26        100619                Dewars 15YR w/2 Rock Glasses    420.75
# ...          ...                                         ...       ...
# 4469      999930           Methanol Moonshine Christmas 2021   6048.00
# 4470      999931          Amrut Bagheeera Single Malt Whisky    450.00
# 4471      999932               Single Malts of India Neidhal    460.44
# 4472      999991                        Legs Diamond Bourbon    270.00
# 4473      999992       Kings County Distillery Aged Gift Set    405.00
#
#       Bottle_Retail  Bottle_Volume  Bottles_Sold
# 5             41.39            750           606
# 12            70.49            750           432
# 21            33.74            750           564
# 25            37.49            750           160
# 26            38.25            750            11
# ...             ...            ...           ...
# 4469          36.00            750           168
# 4470          75.00            750             6
# 4471          76.74            750             6
# 4472          45.00            750             6
# 4473          67.50            600             6
#
# [878 rows x 6 columns]

# %%
mask1 = Moderately_High.Bottle_Volume < 750
Moderately_High[mask1]
# Out:
#      Item_Number                       Item_Description   revenue  \
# 44        100855       Makers Mark Generations Tri-Pack  46410.00
# 145       101564      Ardbeg 10YO Monsters of Smoke VAP  14058.75
# 153       101653               Koval Gin Trio Gift Pack   4803.63
# 154       101654                Koval Whiskey Gift Pack   5850.00
# 1623       48123                            Hennessy XO  35718.17
# 2968      902497                  Remy Martin VSOP Mini   8907.84
# 4473      999992  Kings County Distillery Aged Gift Set    405.00
#
#       Bottle_Retail  Bottle_Volume  Bottles_Sold
# 44        63.750000            375           728
# 145       37.490000            600           375
# 153       42.510000            600           113
# 154       48.750000            600           120
# 1623      85.086154            375           433
# 2968      38.610000            603           229
# 4473      67.500000            600             6

# %%
moderately_high[mask1].shape

# %%
mask2 = moderately_high.Bottle_Volume > 750
moderately_high[mask2]

# %%
sub_clust_dict ={0:'Most_Variety', 1:'Quick_Shots', 2:'Cheap', 3:'Moderately_High'}

# %%
sub_most_variety = everything_else.loc[everything_else.sub_cluster_name== 'Most_Variety']
proc_freq(sub_most_variety,'str_volume')
sub_most_variety.str_volume.value_counts()
# Out:
# 750     1881
# 1000     302
# 800        7
# 850        6
# 900        3
# 950        1
# Name: str_volume, dtype: int64

# %%
 everything_else.loc[everything_else.sub_cluster_name== 'Most_Variety']['New_Category_Name'].value_counts(normalize=True)
# Out:
# Vodkas                                  0.170909
# Whiskies                                0.122273
# Liquers                                 0.115909
# Rum                                     0.098182
# Temporary & Specialty Packages          0.068636
# Special Order Items                     0.067273
# Bourbon                                 0.060455
# Tequila                                 0.056364
# Gin                                     0.052273
# Brandies                                0.041364
# Schnapps                                0.040000
# Scotch                                  0.024091
# American Distilled Spirits Specialty    0.020000
# Imported Distilled Spirits Specialty    0.013636
# Whiskey Liqueur                         0.011818
# Neutral Grain Spirits Flavored          0.011364
# Cocktails                               0.010909
# Mezcal                                  0.007273
# Neutral Grain Spirits                   0.004091
# Triple Sec                              0.003182
# Name: New_Category_Name, dtype: float64

# %%
sub_moderately_high = everything_else.loc[everything_else.sub_cluster_name =='Moderately_High']
proc_freq(sub_moderately_high,'str_volume')
sub_moderately_high.str_volume.value_counts(normalize=True)
# Out:
# 750     0.962415
# 1000    0.026196
# 600     0.004556
# 375     0.002278
# 950     0.001139
# 850     0.001139
# 1200    0.001139
# 603     0.001139
# Name: str_volume, dtype: float64

# %%
everything_else.loc[everything_else.sub_cluster_name =='Moderately_High']['New_Category_Name'].value_counts(normalize=True)
# Out:
# Bourbon                                 0.182232
# Whiskies                                0.175399
# Scotch                                  0.141230
# Tequila                                 0.126424
# Temporary & Specialty Packages          0.097950
# Special Order Items                     0.067198
# Rum                                     0.038724
# Brandies                                0.036446
# Mezcal                                  0.031891
# Imported Distilled Spirits Specialty    0.029613
# Gin                                     0.019362
# Liquers                                 0.019362
# American Distilled Spirits Specialty    0.014806
# Vodkas                                  0.012528
# Whiskey Liqueur                         0.003417
# Cocktails                               0.002278
# Distilled Spirits Specialty             0.001139
# Name: New_Category_Name, dtype: float64

# %%
sub_quick_shots = everything_else.loc[everything_else.sub_cluster_name=='Quick_Shots']
proc_freq(sub_quick_shots,'str_volume')
sub_quick_shots.str_volume.value_counts(normalize=True)
# Out:
# 375    0.391304
# 50     0.334096
# 200    0.194508
# 100    0.068650
# 20     0.004577
# 150    0.002288
# 400    0.002288
# 175    0.002288
# Name: str_volume, dtype: float64

# %%
everything_else.loc[everything_else.sub_cluster_name=='Quick_Shots']['New_Category_Name'].value_counts(normalize=True)
# Out:
# Vodkas                                  0.201373
# Whiskies                                0.157895
# Cocktails                               0.118993
# Liquers                                 0.116705
# Temporary & Specialty Packages          0.070938
# Bourbon                                 0.068650
# Schnapps                                0.059497
# Brandies                                0.054920
# Tequila                                 0.041190
# Rum                                     0.032037
# Gin                                     0.020595
# Imported Distilled Spirits Specialty    0.018307
# Whiskey Liqueur                         0.013730
# Scotch                                  0.009153
# Special Order Items                     0.009153
# American Distilled Spirits Specialty    0.004577
# Neutral Grain Spirits                   0.002288
# Name: New_Category_Name, dtype: float64

# %%
sub_cheap = everything_else.loc[everything_else.sub_cluster_name== 'Cheap']
proc_freq(sub_cheap,'str_volume')
sub_cheap.str_volume.value_counts(normalize=True)
# Out:
# 750     0.404412
# 1000    0.264706
# 375     0.183824
# 200     0.102941
# 100     0.029412
# 50      0.014706
# Name: str_volume, dtype: float64

# %%
everything_else.loc[everything_else.sub_cluster_name== 'Cheap']['New_Category_Name'].value_counts(normalize=True)
# Out:
# Vodkas                                  0.250000
# Whiskies                                0.161765
# Bourbon                                 0.102941
# Rum                                     0.095588
# Brandies                                0.080882
# Tequila                                 0.080882
# Liquers                                 0.073529
# Gin                                     0.036765
# Schnapps                                0.036765
# Whiskey Liqueur                         0.029412
# Triple Sec                              0.022059
# Temporary & Specialty Packages          0.007353
# Neutral Grain Spirits                   0.007353
# Imported Distilled Spirits Specialty    0.007353
# Neutral Grain Spirits Flavored          0.007353
# Name: New_Category_Name, dtype: float64

# %%
everything_else.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3651 entries, 1 to 4474
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Number           3651 non-null   object
#  1   Item_Description      3651 non-null   object
#  2   Bottle_Volume         3651 non-null   int64
#  3   Bottle_Retail         3651 non-null   float64
#  4   Bottles_Sold          3651 non-null   int64
#  5   cluster_name          3651 non-null   object
#  6   revenue               3651 non-null   float64
#  7   Num_Stores_Selling    3651 non-null   int64
#  8   New_Category_Name     3651 non-null   object
#  9   Bottle_Volume_scaled  3651 non-null   float64
#  10  Bottle_Retail_scaled  3651 non-null   float64
#  11  Bottles_Sold_scaled   3651 non-null   float64
#  12  sub_cluster           3651 non-null   int32
#  13  Bottle_Volume_liters  3651 non-null   float64
#  14  price_per_ml          3651 non-null   float64
#  15  str_volume            3651 non-null   object
#  16  sub_cluster_name      3651 non-null   object
# dtypes: float64(7), int32(1), int64(3), object(6)
# memory usage: 499.2+ KB

# %%
everything_else2 = everything_else.copy()

# %%
everything_else2.head()
# Out:
#   Item_Number                                Item_Description  Bottle_Volume  \
# 1       10006                            Scoresby Rare Scotch            750
# 2      100077                        Kraken Rum w/ Tiki Glass            750
# 4       10009                            Scoresby Rare Scotch           1000
# 5      100148      Jack Daniels Single Barrel w/Snifter Glass            750
# 6      100202  Baileys Original Irish Cream w/2 Dessert Bowls            750
#
#    Bottle_Retail  Bottles_Sold     cluster_name   revenue  Num_Stores_Selling  \
# 1           7.70          4619     Most_Variety  35566.30                 197
# 2          15.68          2679     Most_Variety  42006.72                 136
# 4          10.11          1722     Most_Variety  17409.42                  70
# 5          41.39           606  Moderately_High  25082.34                 120
# 6          24.74          3160     Most_Variety  78178.40                 149
#
#                 New_Category_Name  Bottle_Volume_scaled  Bottle_Retail_scaled  \
# 1                          Scotch              0.215130             -0.967835
# 2  Temporary & Specialty Packages              0.215130             -0.499293
# 4                          Scotch              1.401368             -0.826333
# 5  Temporary & Specialty Packages              0.215130              1.010258
# 6  Temporary & Specialty Packages              0.215130              0.032661
#
#    Bottles_Sold_scaled  sub_cluster  Bottle_Volume_liters  price_per_ml  \
# 1             0.019950            0                  0.75      0.010267
# 2            -0.153505            0                  0.75      0.020907
# 4            -0.239070            0                  1.00      0.010110
# 5            -0.338852            3                  0.75      0.055187
# 6            -0.110499            0                  0.75      0.032987
#
#   str_volume sub_cluster_name
# 1        750     Most_Variety
# 2        750     Most_Variety
# 4       1000     Most_Variety
# 5        750  Moderately_High
# 6        750     Most_Variety

# %%
sub_clust_dict ={0:'Most_Variety', 1:'Quick_Shots', 2:'Cheap', 3:'Moderately_High'}
everything_else2['cluster_name'] = everything_else2[['sub_cluster']].apply(lambda current_row: sub_clust_dict[current_row[0]],axis=1)

# %%
everything_else2['cluster_name'].head()
# Out:
# 1       Most_Variety
# 2       Most_Variety
# 4       Most_Variety
# 5    Moderately_High
# 6       Most_Variety
# Name: cluster_name, dtype: object

# %%
keeps = ['Item_Number','Item_Description','Bottle_Volume','Bottle_Retail', 'Bottles_Sold', 'cluster_name',
         'revenue', 'Num_Stores_Selling', 'New_Category_Name']


everything_else_keep = everything_else2[keeps]
everything_else_keep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3651 entries, 1 to 4474
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Item_Number         3651 non-null   object
#  1   Item_Description    3651 non-null   object
#  2   Bottle_Volume       3651 non-null   int64
#  3   Bottle_Retail       3651 non-null   float64
#  4   Bottles_Sold        3651 non-null   int64
#  5   cluster_name        3651 non-null   object
#  6   revenue             3651 non-null   float64
#  7   Num_Stores_Selling  3651 non-null   int64
#  8   New_Category_Name   3651 non-null   object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 285.2+ KB

# %%
prod_clusters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4304 entries, 1 to 4474
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Item_Number         4304 non-null   object
#  1   Item_Description    4304 non-null   object
#  2   Bottle_Volume       4304 non-null   int64
#  3   Bottle_Retail       4304 non-null   float64
#  4   Bottles_Sold        4304 non-null   int64
#  5   cluster_name        4304 non-null   object
#  6   revenue             4304 non-null   float64
#  7   Num_Stores_Selling  4304 non-null   int64
#  8   New_Category_Name   4304 non-null   object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 336.2+ KB

# %%
other_original_clusters = prod_clusters.loc[prod_clusters['cluster_name'] != 'Everything_Else',:]

# %%
everything_else_keep.shape
# Out:
# (3651, 9)

# %%
other_original_clusters.shape
# Out:
# (653, 9)

# %%
prod_clusters.shape
# Out:
# (4304, 9)

# %%
3651 + 653
# Out:
# 4304

# %%
final_clusters = pd.concat([everything_else_keep,other_original_clusters], axis=0)

# %%
final_clusters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4304 entries, 1 to 4457
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Item_Number         4304 non-null   object
#  1   Item_Description    4304 non-null   object
#  2   Bottle_Volume       4304 non-null   int64
#  3   Bottle_Retail       4304 non-null   float64
#  4   Bottles_Sold        4304 non-null   int64
#  5   cluster_name        4304 non-null   object
#  6   revenue             4304 non-null   float64
#  7   Num_Stores_Selling  4304 non-null   int64
#  8   New_Category_Name   4304 non-null   object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 336.2+ KB

# %%
final_clusters['New_Category_Name'].value_counts(normalize=True)
# Out:
# Vodkas                                  0.139870
# Whiskies                                0.139638
# Bourbon                                 0.088058
# Liquers                                 0.081552
# Rum                                     0.079461
# Temporary & Specialty Packages          0.072258
# Tequila                                 0.071097
# Special Order Items                     0.056227
# Scotch                                  0.054600
# Brandies                                0.040892
# Cocktails                               0.040195
# Gin                                     0.039963
# Schnapps                                0.029972
# Imported Distilled Spirits Specialty    0.017193
# American Distilled Spirits Specialty    0.013941
# Whiskey Liqueur                         0.011849
# Mezcal                                  0.011617
# Neutral Grain Spirits Flavored          0.006041
# Neutral Grain Spirits                   0.003020
# Triple Sec                              0.002323
# Distilled Spirits Specialty             0.000232
# Name: New_Category_Name, dtype: float64

# %% [markdown]
# write out final clusters to use in further analysis

# %%
# final_clusters.to_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2021\final_clusters.csv')
