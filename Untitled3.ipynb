# %%
shamrock_spirits = store_trans_cluster.loc[store_trans_cluster.Store_Name == 'Shamrock Spirits',:]
shamrock_spirits.head()

# %%
[s for s in stores.Store_Name if s.find('Double D Liquor Store')!= -1]

# %%
stores.loc[stores.Store_Name.isin(['Double D Liquor Store', 'Double D Liquor Store / Waukon']),:]

# %%
[s for s in stores.Store_Name if s.find("Dyno's Wine and Spirits")!= -1]

# %%
stores.loc[stores.Store_Name.isin(["Dyno's Wine and Spirits / Storm Lake", "Dyno's Wine and Spirits / Pocahontas"]),:]

# %%
import pandas as pd

# %%
final_clusters = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2021\final_clusters.csv',dtype={'Item_Number':str}, index_col=0)

# %%
final_clusters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4301 entries, 1 to 4457
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Item_Number         4301 non-null   object
#  1   Item_Description    4301 non-null   object
#  2   Bottle_Volume       4301 non-null   int64
#  3   Bottle_Retail       4301 non-null   float64
#  4   Bottles_Sold        4301 non-null   int64
#  5   cluster_name        4301 non-null   object
#  6   revenue             4301 non-null   float64
#  7   Num_Stores_Selling  4301 non-null   int64
#  8   New_Category_Name   4301 non-null   object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 336.0+ KB

# %%
final_clusters.cluster_name.value_counts()
# Out:
# Most_Variety         2199
# Moderately_High       877
# Volume_For_Dollar     454
# Quick_Shots           436
# High_End              157
# Cheap                 136
# Popular_Bottles        42
# Name: cluster_name, dtype: int64

# %%
final_clusters.loc[final_clusters.cluster_name == 'Popular_Bottles',['Item_Description','New_Category_Name','Num_Stores_Selling']].sort_values(by='Num_Stores_Selling', ascending=False)
# Out:
#                            Item_Description  \
# 176                 Crown Royal Regal Apple
# 1203                   Titos Handmade Vodka
# 682         Jack Daniels Old #7 Black Label
# 214                            Black Velvet
# 197                             Crown Royal
# 1041                          Hawkeye Vodka
# 1394                         Malibu Coconut
# 1205                   Titos Handmade Vodka
# 922             Absolut Swedish Vodka 80prf
# 2030              Fireball Cinnamon Whiskey
# 1460         Captain Morgan Original Spiced
# 301                                 Jameson
# 210                            Black Velvet
# 159            Black Velvet Toasted Caramel
# 211                            Black Velvet
# 1459         Captain Morgan Original Spiced
# 2032              Fireball Cinnamon Whiskey
# 1182                         Smirnoff 80prf
# 1462         Captain Morgan Original Spiced
# 1202                   Titos Handmade Vodka
# 2048  Fireball Cinnamon Whiskey Mini Sleeve
# 2772                          Patron Silver
# 1037                          Hawkeye Vodka
# 1617                            Hennessy VS
# 1083              McCormick 80prf Vodka PET
# 1039                          Hawkeye Vodka
# 2031          Fireball Cinnamon Whiskey PET
# 1038                      Hawkeye Vodka PET
# 2029              Fireball Cinnamon Whiskey
# 1204                   Titos Handmade Vodka
# 212                            Black Velvet
# 1461         Captain Morgan Original Spiced
# 209                            Black Velvet
# 405   Captain Morgan Original Spiced Barrel
# 1613                            Hennessy VS
# 1082                  McCormick 80prf Vodka
# 2033              Fireball Cinnamon Whiskey
# 198                             Crown Royal
# 683         Jack Daniels Old #7 Black Label
# 2551                             99 Bananas
# 1004                           Barton Vodka
# 2385                      Tortilla Gold DSS
#
#                          New_Category_Name  Num_Stores_Selling
# 176                               Whiskies                1725
# 1203                                Vodkas                1725
# 682                               Whiskies                1711
# 214                               Whiskies                1706
# 197                               Whiskies                1672
# 1041                                Vodkas                1637
# 1394                                   Rum                1584
# 1205                                Vodkas                1581
# 922                                 Vodkas                1566
# 2030                       Whiskey Liqueur                1552
# 1460                                   Rum                1523
# 301                               Whiskies                1485
# 210                               Whiskies                1477
# 159                               Whiskies                1468
# 211                               Whiskies                1457
# 1459                                   Rum                1436
# 2032                       Whiskey Liqueur                1423
# 1182                                Vodkas                1356
# 1462                                   Rum                1344
# 1202                                Vodkas                1303
# 2048                       Whiskey Liqueur                1297
# 2772                               Tequila                1274
# 1037                                Vodkas                1226
# 1617                              Brandies                1205
# 1083                                Vodkas                1175
# 1039                                Vodkas                1160
# 2031                       Whiskey Liqueur                1131
# 1038                                Vodkas                 926
# 2029                       Whiskey Liqueur                 855
# 1204                                Vodkas                 666
# 212                               Whiskies                 621
# 1461                                   Rum                 609
# 209                               Whiskies                 608
# 405                                    Rum                 600
# 1613                              Brandies                 587
# 1082                                Vodkas                 539
# 2033                       Whiskey Liqueur                 522
# 198                               Whiskies                 489
# 683                               Whiskies                 471
# 2551                              Schnapps                 248
# 1004                                Vodkas                 215
# 2385  Imported Distilled Spirits Specialty                  73

# %%
zip_code_database = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\zip_code_database.csv')

# %%
zip_code_database.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42724 entries, 0 to 42723
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   zip                       42724 non-null  int64
#  1   type                      42724 non-null  object
#  2   decommissioned            42724 non-null  int64
#  3   primary_city              42724 non-null  object
#  4   acceptable_cities         9287 non-null   object
#  5   unacceptable_cities       11666 non-null  object
#  6   state                     42724 non-null  object
#  7   county                    41799 non-null  object
#  8   timezone                  41926 non-null  object
#  9   area_codes                39698 non-null  object
#  10  world_region              333 non-null    object
#  11  country                   42650 non-null  object
#  12  latitude                  42724 non-null  float64
#  13  longitude                 42724 non-null  float64
#  14  irs_estimated_population  42724 non-null  int64
# dtypes: float64(2), int64(3), object(10)
# memory usage: 4.9+ MB
