# %%
import pandas as pd
import numpy as np

# %%
dp05_county = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\DP05 Iowa Counties.csv')

# %%
dp05_county
# Out:
#                              Unnamed: 0            Adair County, Iowa  \
# 0                      Label (Grouping)  Adair County, Iowa!!Estimate
# 1                           SEX AND AGE                           NaN
# 2                      Total population                         7,048
# 3                                  Male                         3,510
# 4                                Female                         3,538
# ..                                  ...                           ...
# 90                  Total housing units                         3,709
# 91       CITIZEN, VOTING AGE POPULATION                           NaN
# 92      Citizen, 18 and over population                         5,471
# 93                                 Male                         2,694
# 94                               Female                         2,777
#
#                              Unnamed: 2                   Unnamed: 3  \
# ...
