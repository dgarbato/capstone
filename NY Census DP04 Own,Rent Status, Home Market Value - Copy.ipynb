# %%
import pandas as pd
import numpy as np

# %%
from missing_columns_pd import miss_cols

# %%
dp04 = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\NY ACSDP5Y2020.DP04-2022-04-30T223339.csv')
# Out:
# C:\Users\dgarb\AppData\Local\Temp/ipykernel_2580/2379035287.py:1: DtypeWarning: Columns (885,921,1609,1733,2125,2145,2149,2157,2173,2193,2213,2225,2233,2245,2249,2253,2257,2273,2285,2289,2297,2305,2309,2317,2329,2337,2341,2353,2357,2361,2389,2393,2401,2409,2413,2421,2437,2445,2449,2457,2461,2477,2493,2497,2505,2525,2533,2537,2541,2565,2585,2589,2593,2601,2613,2633,2637,2641,2725,2733,2745,2793,2813,2829,2857,2869,2901,2909,2913,2921,2929,2945,2969,3001,3041,3061,3085,3089,3093,3109,3113,3137,3169,3177,3185,3213,3253,3257,3273,3289,3293,3329,3357,3369,3377,3401,3405,3413,3417,3429,3441,3445,3493,3497,3525,3529,3565,3577,3581,3585,3589,3601,3609,3613,3629,3633,3637,3649,3661,3665,3681,3701,3705,3713,3729,3737,3745,3753,3757,3765,3773,3777,3785,3793,3805,3813,3817,3821,3825,3829,3833,3837,3841,3845,3853,3861,3869,3873,3877,3881,3889,3893,3897,3901,3909,3917,3921,3945,3949,3953,3961,3973,3985,3989,4013,4029,4033,4037,4049,4057,4061,4065,4069,4073,4105,4109,4121,4125,4133,4137,4145,4157,4
# ...

# %%
cols = list(dp04.columns)

# %%
new_cols = list(filter(lambda col: "Estimate" in col,cols)) 

new_cols = ['Label (Grouping)'] + new_cols
new_cols
# Out:
# ['Label (Grouping)',
#  'ZCTA5 50001!!Estimate',
#  'ZCTA5 50002!!Estimate',
#  'ZCTA5 50003!!Estimate',
#  'ZCTA5 50005!!Estimate',
#  'ZCTA5 50006!!Estimate',
#  'ZCTA5 50007!!Estimate',
#  'ZCTA5 50008!!Estimate',
#  'ZCTA5 50009!!Estimate',
#  'ZCTA5 50010!!Estimate',
#  'ZCTA5 50011!!Estimate',
#  'ZCTA5 50012!!Estimate',
#  'ZCTA5 50014!!Estimate',
#  'ZCTA5 50020!!Estimate',
#  'ZCTA5 50021!!Estimate',
#  'ZCTA5 50022!!Estimate',
#  'ZCTA5 50023!!Estimate',
#  'ZCTA5 50025!!Estimate',
#  'ZCTA5 50026!!Estimate',
#  'ZCTA5 50027!!Estimate',
#  'ZCTA5 50028!!Estimate',
#  'ZCTA5 50029!!Estimate',
#  'ZCTA5 50032!!Estimate',
#  'ZCTA5 50033!!Estimate',
#  'ZCTA5 50034!!Estimate',
#  'ZCTA5 50035!!Estimate',
#  'ZCTA5 50036!!Estimate',
#  'ZCTA5 50038!!Estimate',
#  'ZCTA5 50039!!Estimate',
#  'ZCTA5 50041!!Estimate',
#  'ZCTA5 50042!!Estimate',
#  'ZCTA5 50044!!Estimate',
#  'ZCTA5 50046!!Estimate',
#  'ZCTA5 50047!!Estimate',
#  'ZCTA5 50048!!Estimate',
# ...

# %%
# dp04_new 
dp04_new = dp04[new_cols]
dp04_new.head()
# Out:
#                  Label (Grouping) ZCTA5 50001!!Estimate ZCTA5 50002!!Estimate  \
# 0               HOUSING OCCUPANCY                   NaN                   NaN
# 1             Total housing units                   312                   717
# 2          Occupied housing units                   266                   595
# 3            Vacant housing units                    46                   122
# 4          Homeowner vacancy rate                   0.0                   1.1
#
#   ZCTA5 50003!!Estimate ZCTA5 50005!!Estimate ZCTA5 50006!!Estimate  \
# 0                   NaN                   NaN                   NaN
# 1                 3,231                   420                   772
# 2                 3,075                   380                   687
# 3                   156                    40                    85
# 4                   0.0                   0.0                   1.0
#
#   ZCTA5 50007!!Estimate ZCTA5 50008!!Estimate ZCTA5 50009!!Estimate  \
# ...

# %%
pd.set_option('display.max_rows', 146)
dp04_new.head(105)
# Out:
#                                       Label (Grouping) ZCTA5 50001!!Estimate  \
# 0                                    HOUSING OCCUPANCY                   NaN
# 1                                  Total housing units                   312
# 2                               Occupied housing units                   266
# 3                                 Vacant housing units                    46
# 4                               Homeowner vacancy rate                   0.0
# 5                                  Rental vacancy rate                   0.0
# 6                                   UNITS IN STRUCTURE                   NaN
# 7                                  Total housing units                   312
# 8                                     1-unit, detached                   276
# 9                                     1-unit, attached                     0
# 10                                             2 units                     0
# ...

# %%
# 
dp04_new = dp04_new.drop(range(0,49)).reset_index()

# %%
pd.set_option('display.max_rows', 146)
dp04_new.head(105)
# Out:
#      index                                   Label (Grouping)  \
# 0       49                                     HOUSING TENURE
# 1       50                             Occupied housing units
# 2       51                                     Owner-occupied
# 3       52                                    Renter-occupied
# 4       53          Average household size of owner-occupi...
# 5       54          Average household size of renter-occup...
# 6       55                   YEAR HOUSEHOLDER MOVED INTO UNIT
# 7       56                             Occupied housing units
# 8       57                             Moved in 2019 or later
# 9       58                              Moved in 2015 to 2018
# 10      59                              Moved in 2010 to 2014
# 11      60                              Moved in 2000 to 2009
# 12      61                              Moved in 1990 to 1999
# 13      62                          Moved in 1989 and earlier
# ...

# %%
# dp04_new = 
dp04_new = dp04_new.drop(range(6,41)).reset_index()

# %%
pd.set_option('display.max_rows', 146)
dp04_new
# Out:
#     level_0  index                                   Label (Grouping)  \
# 0         0     49                                     HOUSING TENURE
# 1         1     50                             Occupied housing units
# 2         2     51                                     Owner-occupied
# 3         3     52                                    Renter-occupied
# 4         4     53          Average household size of owner-occupi...
# 5         5     54          Average household size of renter-occup...
# 6        41     90                                              VALUE
# 7        42     91                               Owner-occupied units
# 8        43     92                                  Less than $50,000
# 9        44     93                                 $50,000 to $99,999
# 10       45     94                               $100,000 to $149,999
# 11       46     95                               $150,000 to $199,999
# ...

# %%
dp04_new = dp04_new.drop(['level_0', 'index'],axis=1)
dp04_new
# Out:
#                                      Label (Grouping) ZCTA5 50001!!Estimate  \
# 0                                      HOUSING TENURE                   NaN
# 1                              Occupied housing units                   266
# 2                                      Owner-occupied                   233
# 3                                     Renter-occupied                    33
# 4           Average household size of owner-occupi...                  2.73
# 5           Average household size of renter-occup...                  3.42
# 6                                               VALUE                   NaN
# 7                                Owner-occupied units                   233
# 8                                   Less than $50,000                     5
# 9                                  $50,000 to $99,999                    23
# 10                               $100,000 to $149,999                    35
# ...

# %%
# stop  dp04_new = 
dp04_new = dp04_new.drop(range(17,76))

# %%
dp04_new
# Out:
#                                      Label (Grouping) ZCTA5 50001!!Estimate  \
# 0                                      HOUSING TENURE                   NaN
# 1                              Occupied housing units                   266
# 2                                      Owner-occupied                   233
# 3                                     Renter-occupied                    33
# 4           Average household size of owner-occupi...                  2.73
# 5           Average household size of renter-occup...                  3.42
# 6                                               VALUE                   NaN
# 7                                Owner-occupied units                   233
# 8                                   Less than $50,000                     5
# 9                                  $50,000 to $99,999                    23
# 10                               $100,000 to $149,999                    35
# ...

# %%
def get_zip(string):
    L = string.split()
    L2 = L[1]
    L3 = L2.split('!!')
    zip = L3[0]
    return(zip)

# %%
cols = list(dp04_new.columns)

# %%
new_cols = ['Label' if 'Label' in col_name   else get_zip(col_name) for col_name in cols]

# %% [markdown]
# Change column names to zip codes

# %%
dp04_new.columns = new_cols

# %%
dp04_new.head()
# Out:
#                                                Label 50001 50002  50003 50005  \
# 0                                     HOUSING TENURE   NaN   NaN    NaN   NaN
# 1                             Occupied housing units   266   595  3,075   380
# 2                                     Owner-occupied   233   438  2,429   307
# 3                                    Renter-occupied    33   157    646    73
# 4          Average household size of owner-occupi...  2.73  2.38   2.66  2.93
#
#   50006 50007 50008  50009   50010  ...  52776 52777  52778 52801  52802  \
# 0   NaN   NaN   NaN    NaN     NaN  ...    NaN   NaN    NaN   NaN    NaN
# 1   687   186   378  7,327  14,239  ...  1,619   526  1,603   759  3,853
# 2   470   186   304  5,165   7,673  ...  1,209   442  1,336     9  2,648
# 3   217     0    74  2,162   6,566  ...    410    84    267   750  1,205
# 4  2.27  2.99  2.41   2.75    2.32  ...   3.25  2.53   2.42  2.22   2.47
#
#    52803   52804   52806  52807 56027
# ...

# %% [markdown]
# Transpose DataFrame

# %%
dp04_new= dp04_new.set_index('Label').T

# %%
dp04_new
# Out:
# Label HOUSING TENURE     Occupied housing units         Owner-occupied  \
# 50001            NaN                        266                    233
# 50002            NaN                        595                    438
# 50003            NaN                      3,075                  2,429
# 50005            NaN                        380                    307
# 50006            NaN                        687                    470
# ...              ...                        ...                    ...
# 52803            NaN                      8,593                  5,694
# 52804            NaN                     10,782                  7,125
# 52806            NaN                     10,804                  7,229
# 52807            NaN                      6,535                  3,776
# 56027            NaN                        320                    255
#
# Label         Renter-occupied  \
# 50001                      33
# 50002                     157
# ...

# %%
dp04_new.columns = dp04_new.columns.str.replace(' ','_')

# %%
dp04_new
# Out:
# Label HOUSING_TENURE     Occupied_housing_units         Owner-occupied  \
# 50001            NaN                        266                    233
# 50002            NaN                        595                    438
# 50003            NaN                      3,075                  2,429
# 50005            NaN                        380                    307
# 50006            NaN                        687                    470
# ...              ...                        ...                    ...
# 52803            NaN                      8,593                  5,694
# 52804            NaN                     10,782                  7,125
# 52806            NaN                     10,804                  7,229
# 52807            NaN                      6,535                  3,776
# 56027            NaN                        320                    255
#
# Label         Renter-occupied  \
# 50001                      33
# 50002                     157
# ...

# %%
dp04_new
# Out:
# Label HOUSING_TENURE     Occupied_housing_units         Owner-occupied  \
# 50001            NaN                        266                    233
# 50002            NaN                        595                    438
# 50003            NaN                      3,075                  2,429
# 50005            NaN                        380                    307
# 50006            NaN                        687                    470
# ...              ...                        ...                    ...
# 52803            NaN                      8,593                  5,694
# 52804            NaN                     10,782                  7,125
# 52806            NaN                     10,804                  7,229
# 52807            NaN                      6,535                  3,776
# 56027            NaN                        320                    255
#
# Label         Renter-occupied  \
# 50001                      33
# 50002                     157
# ...

# %%
dp04_new = dp04_new.reset_index()

# %%
dp04_new.head()
dp04_new.rename({'index':'Zip_Code'},axis=1, inplace=True)
dp04_new.head()
# Out:
# Label Zip_Code HOUSING_TENURE     Occupied_housing_units  \
# 0        50001            NaN                        266
# 1        50002            NaN                        595
# 2        50003            NaN                      3,075
# 3        50005            NaN                        380
# 4        50006            NaN                        687
#
# Label         Owner-occupied         Renter-occupied  \
# 0                        233                      33
# 1                        438                     157
# 2                      2,429                     646
# 3                        307                      73
# 4                        470                     217
#
# Label         Average_household_size_of_owner-occupied_unit  \
# 0                                                   2.73
# 1                                                   2.38
# 2                                                   2.66
# 3                                                   2.93
# ...

# %%
miss_cols(dp04_new)
# Out:
# [('HOUSING_TENURE', 935, 1.0), ('VALUE', 935, 1.0)]

# %%
dp04_new['HOUSING_TENURE'].fillna("HOUSING_TENURE",inplace = True)
dp04_new['VALUE'].fillna("VALUE",inplace = True)

# %%
miss_cols(dp04_new)
# Out:
# []

# %%
# list(dp04_new.columns)

# %%
dp04_new.head()
# Out:
# Label Zip_Code  HOUSING_TENURE     Occupied_housing_units  \
# 0        50001  HOUSING_TENURE                        266
# 1        50002  HOUSING_TENURE                        595
# 2        50003  HOUSING_TENURE                      3,075
# 3        50005  HOUSING_TENURE                        380
# 4        50006  HOUSING_TENURE                        687
#
# Label         Owner-occupied         Renter-occupied  \
# 0                        233                      33
# 1                        438                     157
# 2                      2,429                     646
# 3                        307                      73
# 4                        470                     217
#
# Label         Average_household_size_of_owner-occupied_unit  \
# 0                                                   2.73
# 1                                                   2.38
# 2                                                   2.66
# ...

# %%
# dp04_new.to_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\dp04_new_housing.csv')
