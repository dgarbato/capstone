# %%
import pandas as pd
import numpy as np

# %%
categories = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2021\catefories_2021.csv',index_col=0)

# %%
categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 390061 to 1094183
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Category       57 non-null     int64
#  1   Category_Name  57 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.3+ KB

# %%
rum = '1062300', '1062100', '1062400', '1062200'

vodka = '1031200','1031000','1031100','1032200','1032000','1032100' OK

Liquers = '1081300', '1081000', '1081400', '1081100', '1081200', '1082100', '1082000', '1082200', '1081600'

gin = '1041100','1041300', '1041200','1042100','1042000'

# %%
categories['category_lower'] =  categories.Category_Name.str.lower()
# categories['category_lower']

# %%
whiskies


[name for name in [string.lower() for string in categories.Category_Name] if name.find('whiskies') != -1]
# Out:
# ['american whiskies',
#  'imported whiskies',
#  'corn whiskies',
#  'single barrel bourbon whiskies',
#  'straight rye whiskies',
#  'irish whiskies',
#  'scotch whiskies',
#  'blended whiskies',
#  'canadian whiskies',
#  'straight bourbon whiskies',
#  'tennessee whiskies']

# %%
vodkas = ['imported vodka', 'american vodka', 'imported vodkas', 'imported flavored vodka', 'american flavored vodka', 'american vodkas']
rum = ['aged dark rum', 'gold rum', 'flavored rum', 'white rum', 'spiced rum']
bourbon = ['bottled in bond bourbon', \
 'single barrel bourbon whiskies','straight bourbon whiskies']
gin = ['imported gins',
 'flavored gin',
 'american sloe gins',
 'imported dry gins',
 'american dry gins']

liquers = ['american cordials & liqueurs',
 'american cordials & liqueur',
 'imported cordials & liqueur',
 'coffee liqueurs',
 'imported cordials & liqueurs',
 'cream liqueurs',
 'whiskey liqueur']

# %%
categories['new_category'] = np.where(categories.category_lower.isin(bourbon), 'Bourbon',
                                      np.where(categories.category_lower.isin([['scotch whiskies', 'single malt scotch']]), 'Scotch',
                                               np.where(categories.category_lower.isin(['imported brandies', 'american brandies']), 'Brandies',
                                                        np.where(categories.category_lower.isin(vodkas), 'Vodkas',
                                                                 np.where(categories.category_lower.isin(rum),'Rum',
                                                                          np.where(categories.category_lower.isin(liquers), 'Liquers',
                                                                                   np.where(categories.category_lower.isin(gin), 'Gin',
                                                                                            np.where(categories.category_lower.isin(liquers), 'Liquers', 'other'  ))))))))

# %%
categories
# Out:
#          Category                         Category_Name  \
# 390061    1070100       Temporary  & Specialty Packages
# 2334587   1070000                       Cocktails / RTD
# 2362487   1011000                     American Whiskies
# 5107      1012000                     Imported Whiskies
# 755128    1032000                        Imported Vodka
# 1064863   1091000  American Distilled Spirits Specialty
# 1063980   1042000                         Imported Gins
# 1068956   1031000                        American Vodka
# 1083167   1090000           Distilled Spirits Specialty
# 1068135   1092000  Imported Distilled Spirits Specialty
# 1074150   1901200                   Special Order Items
# 1067067   1081000          American Cordials & Liqueurs
# 1086346                 straight rye whiskies        other
# 1086377                        irish whiskies        other
# 1086379           american cordials & liqueur      Liquers
# 1086376                              gold rum          Rum
# 1086375           imported cordials & liqueur      Liquers
# 1086291                       scotch whiskies        other
# 1086219                     imported dry gins          Gin
# 1086228                       coffee liqueurs      Liquers
# 1086232                          flavored rum          Rum
# 1086214                             white rum          Rum
# 1086199                    single malt scotch        other
# 1086202        temporary & specialty packages        other
# 1086204                     american dry gins          Gin
# 1086206                            spiced rum          Rum
# 1086212                        cocktails /rtd        other
# 1086242                     imported schnapps        other
# 1086269                       imported vodkas       Vodkas
# 1086272                     imported brandies     Brandies
# 1086273               imported flavored vodka       Vodkas
# 1086275                    100% agave tequila        other
# 1086276                     american brandies     Brandies
# 1086285                      blended whiskies        other
# 1086266          imported cordials & liqueurs      Liquers
# 1086265                        cream liqueurs      Liquers
# 1086247                         mixto tequila        other
# 1086249                     canadian whiskies        other
# 1086254             straight bourbon whiskies      Bourbon
# 1086257   american distilled spirit specialty        other
# 1086259                     american schnapps        other
# 1086260                    tennessee whiskies        other
# 1086261               american flavored vodka       Vodkas
# 1086262        neutral grain spirits flavored        other
# 1086241                       whiskey liqueur      Liquers
# 1094183                       american vodkas       Vodkas

# %%
# bourbon
[name for name in [string.lower() for string in categories.Category_Name] if name.find('bourbon') != -1]
# Out:
# ['bottled in bond bourbon',
#  'single barrel bourbon whiskies',
#  'straight bourbon whiskies']

# %%
# scotch
[name for name in [string.lower() for string in categories.Category_Name] if name.find('scotch') != -1]
# Out:
# ['scotch whiskies', 'single malt scotch']

# %%
# tequila
[name for name in [string.lower() for string in categories.Category_Name] if name.find('tequila') != -1]
# Out:
# ['100% agave tequila', 'mixto tequila']

# %%
Irish Whiskies

# %%
# brandies
[name for name in [string.lower() for string in categories.Category_Name] if name.find('brandies') != -1]
# Out:
# ['imported brandies', 'american brandies']

# %%
# vodka
[name for name in [string.lower() for string in categories.Category_Name] if name.find('vodka') != -1]
# Out:
# ['imported vodka',
#  'american vodka',
#  'imported vodkas',
#  'imported flavored vodka',
#  'american flavored vodka',
#  'american vodkas']

# %%
# rum
[name for name in [string.lower() for string in categories.Category_Name] if name.find('rum') != -1]
# Out:
# ['aged dark rum', 'gold rum', 'flavored rum', 'white rum', 'spiced rum']

# %%
# gin
[name for name in [string.lower() for string in categories.Category_Name] if name.find('gin') != -1]
# Out:
# ['imported gins',
#  'flavored gin',
#  'american sloe gins',
#  'imported dry gins',
#  'american dry gins']

# %%
# schnapps
[name for name in [string.lower() for string in categories.Category_Name] if name.find('schnapps') != -1]
# Out:
# ['imported schnapps', 'american schnapps']

# %%
# liqueur
[name for name in [string.lower() for string in categories.Category_Name] if name.find('liqueur') != -1]
# Out:
# ['american cordials & liqueurs',
#  'american cordials & liqueur',
#  'imported cordials & liqueur',
#  'coffee liqueurs',
#  'imported cordials & liqueurs',
#  'cream liqueurs',
#  'whiskey liqueur']

# %%
# df.sort_values(by=['Population'], ascending=False)
categories.sort_values(by=['Category_Name', 'Category'])
# Out:
#          Category                         Category_Name
# 1086275   1022200                    100% Agave Tequila
# 1086664   1062300                         Aged Dark Rum
# 1086276   1051100                     American Brandies
# 1086379   1081300           American Cordials & Liqueur
# 1067067   1081000          American Cordials & Liqueurs
# 1086257   1091100   American Distilled Spirit Specialty
# 1064863   1091000  American Distilled Spirits Specialty
# 1086204   1041100                     American Dry Gins
# 1086261   1031200               American Flavored Vodka
# 1086259   1081400                     American Schnapps
# 1085292   1041300                    American Sloe Gins
# 1068956   1031000                        American Vodka
# 1094183   1031100                       American Vodkas
# 2362487   1011000                     American Whiskies
# 1086285   1011100                      Blended Whiskies
# 1086749   1011500               Bottled in Bond Bourbon
# 1086249   1012100                     Canadian Whiskies
# 2334587   1070000                       Cocktails / RTD
# 1086212   1071100                        Cocktails /RTD
# 1086228   1081100                       Coffee Liqueurs
# 1085281   1011700                         Corn Whiskies
# 1086265   1081200                        Cream Liqueurs
# 1083167   1090000           Distilled Spirits Specialty
# 1082703   1041200                          Flavored Gin
# 1086232   1062500                          Flavored Rum
# 1086376   1062100                              Gold Rum
# 1086272   1052100                     Imported Brandies
# 1086375   1082100           Imported Cordials & Liqueur
# 1086266   1082000          Imported Cordials & Liqueurs
# 1087885   1092100   Imported Distilled Spirit Specialty
# 1068135   1092000  Imported Distilled Spirits Specialty
# 1086219   1042100                     Imported Dry Gins
# 1086273   1032200               Imported Flavored Vodka
# 1063980   1042000                         Imported Gins
# 1086242   1082200                     Imported Schnapps
# 755128    1032000                        Imported Vodka
# 1086269   1032100                       Imported Vodkas
# 5107      1012000                     Imported Whiskies
# 1086377   1012400                        Irish Whiskies
# 1086052   1022300                                Mezcal
# 1086247   1022100                         Mixto Tequila
# 1085543   1091200                 Neutral Grain Spirits
# 1086262   1091300        Neutral Grain Spirits Flavored
# 1086291   1012200                       Scotch Whiskies
# 1086108   1011300        Single Barrel Bourbon Whiskies
# 1086199   1012300                    Single Malt Scotch
# 1074150   1901200                   Special Order Items
# 1086206   1062400                            Spiced Rum
# 1086254   1011200             Straight Bourbon Whiskies
# 1086346   1011600                 Straight Rye Whiskies
# 390061    1070100       Temporary  & Specialty Packages
# 1087950   1700000       Temporary &  Specialty Packages
# 1086202   1701100        Temporary & Specialty Packages
# 1086260   1011400                    Tennessee Whiskies
# 1085959   1081500                            Triple Sec
# 1086241   1081600                       Whiskey Liqueur
# 1086214   1062200                             White Rum
