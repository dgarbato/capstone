# %%
import pandas as pd
import numpy as np

# %%
from missing_columns_pd import miss_cols

# %%
dp05 = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\NY ACSDP5Y2020.DP05-2022-04-30T192403.csv')

# %%
dp05.head()
# Out:
#                             Label (Grouping)  ZCTA5 06390!!Estimate  \
# 0                                SEX AND AGE                    NaN
# 1                           Total population                   61.0
# 2                                       Male                   28.0
# 3                                     Female                   33.0
# 4          Sex ratio (males per 100 females)                   84.8
#
#   ZCTA5 06390!!Margin of Error ZCTA5 06390!!Percent  \
# 0                          NaN                  NaN
# 1                          ±36                   61
# 2                          ±18                45.9%
# 3                          ±23                54.1%
# 4                        ±53.0                  (X)
#
#   ZCTA5 06390!!Percent Margin of Error ZCTA5 10001!!Estimate  \
# 0                                  NaN                   NaN
# 1                                  (X)                25,026
# ...

# %%
cols = list(dp05.columns)
cols
# Out:
# ['Label (Grouping)',
#  'ZCTA5 06390!!Estimate',
#  'ZCTA5 06390!!Margin of Error',
#  'ZCTA5 06390!!Percent',
#  'ZCTA5 06390!!Percent Margin of Error',
#  'ZCTA5 10001!!Estimate',
#  'ZCTA5 10001!!Margin of Error',
#  'ZCTA5 10001!!Percent',
#  'ZCTA5 10001!!Percent Margin of Error',
#  'ZCTA5 10002!!Estimate',
#  'ZCTA5 10002!!Margin of Error',
#  'ZCTA5 10002!!Percent',
#  'ZCTA5 10002!!Percent Margin of Error',
#  'ZCTA5 10003!!Estimate',
#  'ZCTA5 10003!!Margin of Error',
#  'ZCTA5 10003!!Percent',
#  'ZCTA5 10003!!Percent Margin of Error',
#  'ZCTA5 10004!!Estimate',
#  'ZCTA5 10004!!Margin of Error',
#  'ZCTA5 10004!!Percent',
#  'ZCTA5 10004!!Percent Margin of Error',
#  'ZCTA5 10005!!Estimate',
#  'ZCTA5 10005!!Margin of Error',
#  'ZCTA5 10005!!Percent',
#  'ZCTA5 10005!!Percent Margin of Error',
#  'ZCTA5 10006!!Estimate',
#  'ZCTA5 10006!!Margin of Error',
#  'ZCTA5 10006!!Percent',
#  'ZCTA5 10006!!Percent Margin of Error',
#  'ZCTA5 10007!!Estimate',
# ...

# %%
new_cols = list(filter(lambda col: "Estimate" in col,cols)) 
# new_cols.append('Label (Grouping)')
new_cols = ['Label (Grouping)'] + new_cols
# new_cols

# %%
dp05_new = dp05[new_cols]

# %%
pd.set_option('display.max_rows', 95)
dp05_new.head(95)
# Out:
#                                      Label (Grouping)  ZCTA5 06390!!Estimate  \
# 0                                         SEX AND AGE                    NaN
# 1                                    Total population                   61.0
# 2                                                Male                   28.0
# 3                                              Female                   33.0
# 4                   Sex ratio (males per 100 females)                   84.8
# 5                                       Under 5 years                    9.0
# 6                                        5 to 9 years                    1.0
# 7                                      10 to 14 years                    4.0
# 8                                      15 to 19 years                    3.0
# 9                                      20 to 24 years                    4.0
# 10                                     25 to 34 years                    8.0
# ...

# %%
dp05_new = dp05_new.drop([0])

# %%
dp05_new =  dp05_new.drop(range(25,94))

# %%
dp05_new
# Out:
#                              Label (Grouping)  ZCTA5 06390!!Estimate  \
# 1                            Total population                   61.0
# 2                                        Male                   28.0
# 3                                      Female                   33.0
# 4           Sex ratio (males per 100 females)                   84.8
# 5                               Under 5 years                    9.0
# 6                                5 to 9 years                    1.0
# 7                              10 to 14 years                    4.0
# 8                              15 to 19 years                    3.0
# 9                              20 to 24 years                    4.0
# 10                             25 to 34 years                    8.0
# 11                             35 to 44 years                   11.0
# 12                             45 to 54 years                    9.0
# 13                             55 to 59 years                    0.0
# ...

# %%
dp05_new.shape
# Out:
# (24, 1795)

# %%
cols = list(dp05_new.columns)
len(cols)
# Out:
# 1795

# %%
cols
# Out:
# ['Label (Grouping)',
#  'ZCTA5 06390!!Estimate',
#  'ZCTA5 10001!!Estimate',
#  'ZCTA5 10002!!Estimate',
#  'ZCTA5 10003!!Estimate',
#  'ZCTA5 10004!!Estimate',
#  'ZCTA5 10005!!Estimate',
#  'ZCTA5 10006!!Estimate',
#  'ZCTA5 10007!!Estimate',
#  'ZCTA5 10009!!Estimate',
#  'ZCTA5 10010!!Estimate',
#  'ZCTA5 10011!!Estimate',
#  'ZCTA5 10012!!Estimate',
#  'ZCTA5 10013!!Estimate',
#  'ZCTA5 10014!!Estimate',
#  'ZCTA5 10016!!Estimate',
#  'ZCTA5 10017!!Estimate',
#  'ZCTA5 10018!!Estimate',
#  'ZCTA5 10019!!Estimate',
#  'ZCTA5 10020!!Estimate',
#  'ZCTA5 10021!!Estimate',
#  'ZCTA5 10022!!Estimate',
#  'ZCTA5 10023!!Estimate',
#  'ZCTA5 10024!!Estimate',
#  'ZCTA5 10025!!Estimate',
#  'ZCTA5 10026!!Estimate',
#  'ZCTA5 10027!!Estimate',
#  'ZCTA5 10028!!Estimate',
#  'ZCTA5 10029!!Estimate',
#  'ZCTA5 10030!!Estimate',
#  'ZCTA5 10031!!Estimate',
#  'ZCTA5 10032!!Estimate',
#  'ZCTA5 10033!!Estimate',
#  'ZCTA5 10034!!Estimate',
#  'ZCTA5 10035!!Estimate',
# ...

# %%
L = 'ZCTA5 50001!!Estimate'.split()
L2 = L[1]
L2
L3 = L2.split('!!')
zip = L3[0]
zip
# Out:
# '50001'

# %%
def get_zip(string):
    L = string.split()
    L2 = L[1]
    L2
    L3 = L2.split('!!')
    zip = L3[0]
    return(zip)

# %%
get_zip('ZCTA5 06390!!Estimate')
# Out:
# '06390'

# %%
len(cols)
# Out:
# 1795

# %%
# new_cols = []
# for col_name in cols:
#     if col_name[0:6] == 'Label':
#         new_cols.append('Label')
        
#     elif col_name[0:6] == 'ZCTA5':
#         new_col_name = get_zip(col_name)
#         new_cols.append(new_col_name)

# %%
new_cols = ['Label' if 'Label' in col_name   else get_zip(col_name) for col_name in cols]

# %%
len(new_cols)
# Out:
# 1795

# %%
new_cols
# Out:
# ['Label',
#  '06390',
#  '10001',
#  '10002',
#  '10003',
#  '10004',
#  '10005',
#  '10006',
#  '10007',
#  '10009',
#  '10010',
#  '10011',
#  '10012',
#  '10013',
#  '10014',
#  '10016',
#  '10017',
#  '10018',
#  '10019',
#  '10020',
#  '10021',
#  '10022',
#  '10023',
#  '10024',
#  '10025',
#  '10026',
#  '10027',
#  '10028',
#  '10029',
#  '10030',
#  '10031',
#  '10032',
#  '10033',
#  '10034',
#  '10035',
#  '10036',
#  '10037',
#  '10038',
#  '10039',
#  '10040',
#  '10044',
#  '10065',
#  '10069',
#  '10075',
#  '10103',
#  '10110',
#  '10111',
#  '10112',
#  '10115',
#  '10119',
#  '10128',
#  '10152',
#  '10153',
#  '10154',
#  '10162',
#  '10165',
#  '10167',
#  '10168',
#  '10169',
#  '10170',
#  '10171',
#  '10172',
#  '10173',
#  '10174',
#  '10177',
#  '10199',
#  '10271',
#  '10278',
#  '10279',
#  '10280',
#  '10282',
#  '10301',
#  '10302',
#  '10303',
#  '10304',
#  '10305',
#  '10306',
#  '10307',
#  '10308',
#  '10309',
#  '10310',
#  '10311',
#  '10312',
# ...

# %% [markdown]
# assign new column names

# %%
dp05_new.shape
# Out:
# (24, 1795)

# %%
# df.columns=['com', 'year', 'production_Moz']
dp05_new.columns = new_cols

# %%
dp05_new.shape
# Out:
# (24, 1795)

# %% [markdown]
# transpose data frame

# %%
dp05_new = dp05_new.set_index('Label').T

# %%
dp05_new.shape
# Out:
# (1794, 24)

# %%
dp05_new.head()
# Out:
# Label     Total population         Male         Female  \
# 06390                 61.0         28.0           33.0
# 10001               25,026       12,265         12,761
# 10002               74,363       36,656         37,707
# 10003               54,671       26,671         28,000
# 10004                3,310        1,567          1,743
#
# Label         Sex ratio (males per 100 females)         Under 5 years  \
# 06390                                      84.8                   9.0
# 10001                                      96.1                   866
# 10002                                      97.2                 2,241
# 10003                                      95.3                 1,549
# 10004                                      89.9                   108
#
# Label         5 to 9 years         10 to 14 years         15 to 19 years  \
# 06390                  1.0                    4.0                    3.0
# ...

# %%
dp05_new.columns = dp05_new.columns.str.replace(' ','_')

# %%
dp05_new.head()
# Out:
# Label     Total_population         Male         Female  \
# 06390                 61.0         28.0           33.0
# 10001               25,026       12,265         12,761
# 10002               74,363       36,656         37,707
# 10003               54,671       26,671         28,000
# 10004                3,310        1,567          1,743
#
# Label         Sex_ratio_(males_per_100_females)         Under_5_years  \
# 06390                                      84.8                   9.0
# 10001                                      96.1                   866
# 10002                                      97.2                 2,241
# 10003                                      95.3                 1,549
# 10004                                      89.9                   108
#
# Label         5_to_9_years         10_to_14_years         15_to_19_years  \
# 06390                  1.0                    4.0                    3.0
# ...

# %%
dp05_new = dp05_new.reset_index()
# dp05_new.reset_index()

# %%
dp05_new.head()
# Out:
# Label  index     Total_population         Male         Female  \
# 0      06390                 61.0         28.0           33.0
# 1      10001               25,026       12,265         12,761
# 2      10002               74,363       36,656         37,707
# 3      10003               54,671       26,671         28,000
# 4      10004                3,310        1,567          1,743
#
# Label         Sex_ratio_(males_per_100_females)         Under_5_years  \
# 0                                          84.8                   9.0
# 1                                          96.1                   866
# 2                                          97.2                 2,241
# 3                                          95.3                 1,549
# 4                                          89.9                   108
#
# Label         5_to_9_years         10_to_14_years         15_to_19_years  \
# 0                      1.0                    4.0                    3.0
# ...

# %%
# unique_cluster_item_list_df.rename({'Item_Number':'cluster_unique_items'} ,axis=1, inplace=True)
dp05_new.rename({'index':'Zip_Code'},axis=1, inplace=True) #inplace=True

# %%
cols = list(dp05_new.columns)
new_cols = [col.strip() for col in cols]
dp05_new.columns = new_cols

# %%
dp05_new.head()
# Out:
#   Zip_Code Total_population    Male  Female Sex_ratio_(males_per_100_females)  \
# 0    06390             61.0    28.0    33.0                              84.8
# 1    10001           25,026  12,265  12,761                              96.1
# 2    10002           74,363  36,656  37,707                              97.2
# 3    10003           54,671  26,671  28,000                              95.3
# 4    10004            3,310   1,567   1,743                              89.9
#
#   Under_5_years 5_to_9_years 10_to_14_years 15_to_19_years 20_to_24_years  \
# 0           9.0          1.0            4.0            3.0            4.0
# 1           866          667            995          1,050          1,898
# 2         2,241        3,023          3,203          2,361          4,593
# 3         1,549          819            865          7,218          5,809
# 4           108           53             48            116             86
#
# ...

# %%
dp05_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1794 entries, 0 to 1793
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Zip_Code                           1794 non-null   object
#  1   Total_population                   1794 non-null   object
#  2   Male                               1794 non-null   object
#  3   Female                             1794 non-null   object
#  4   Sex_ratio_(males_per_100_females)  1794 non-null   object
#  5   Under_5_years                      1794 non-null   object
#  6   5_to_9_years                       1794 non-null   object
#  7   10_to_14_years                     1794 non-null   object
#  8   15_to_19_years                     1794 non-null   object
#  9   20_to_24_years                     1794 non-null   object
#  10  25_to_34_years                     1794 non-null   object
# ...

# %%
dp05_new.shape
# Out:
# (1794, 25)

# %%
miss_cols(dp05_new)
# Out:
# []

# %% [markdown]
# write out DataFrame: dp05_new

# %%
# dp05_new.to_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\dp05_pop_gender_age_estimates.csv')

# %%
# What below does: if x is a string remove the comma and change the type to float


pop = [float(x) if type(x) == str else x for x in [x.replace(',','') if type(x) == str else x for x in dp05_new.Total_population ]]
len(pop)
# Out:
# 1794

# %%
NY_pop_per_zip_df = dp05_new[['Zip_Code','Total_population']]
NY_pop_per_zip_df['population_per_zip'] = pd.Series(pop )
NY_pop_per_zip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1794 entries, 0 to 1793
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Zip_Code            1794 non-null   object
#  1   Total_population    1794 non-null   object
#  2   population_per_zip  1794 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.2+ KB
# C:\Users\dgarb\AppData\Local\Temp/ipykernel_19216/2862215692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NY_pop_per_zip_df['population_per_zip'] = pd.Series(pop )

# %%
NY_pop_per_zip_df = NY_pop_per_zip_df.drop(columns=['Total_population'])

# %% [markdown]
# write out DataFrame: NY_pop_per_zip_df

# %%
NY_pop_per_zip_df.to_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\NY_pop_per_zip_df.csv')
