# %%
import pandas as pd
import numpy as np

# %%
from missing_columns_pd  import miss_cols

# %%
cdtype ={'Zip_Code':str}

# %%
census_combined4 = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\census_combined4.csv',dtype={'Zip_Code':str},index_col=0)

# %%
# square_miles_zip = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\Iowa  square miles  for each zip code copied.csv', encoding= 'unicode_escape',dtype={'ZIP Code':str})

# %%
# miss_cols(square_miles_zip)

# %%
pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', None)
census_combined4.head()
# Out:
#   Zip_Code  pct_Married-couple_household  pct_High_school_graduate_or_higher  \
# 0    50001                          68.8                                94.2
# 1    50002                          64.4                                99.3
# 2    50003                          60.7                                95.0
# 3    50005                          64.5                                93.5
# 4    50006                          54.9                                91.6
#
#    pct_Bachelors_degree_or_higher  Total_population    Male  Female  \
# 0                            31.8             749.0   331.0   418.0
# 1                            18.0            1359.0   687.0   672.0
# 2                            44.9            7872.0  3929.0  3943.0
# 3                            11.6            1060.0   462.0   598.0
# 4                            18.0            1596.0   821.0   775.0
#
#    Sex_ratio_(males_per_100_females)  Under_5_years  5_to_9_years  \
# ...

# %%
miss_cols(census_combined4)
# Out:
# [('pct_mgmnt_sc_bs_art', 3, 0.0032),
#  ('population_per_store', 2, 0.0021),
#  ('population_growth', 1, 0.0011)]

# %%
census_combined4.head()
# Out:
#   Zip_Code  pct_Married-couple_household  pct_High_school_graduate_or_higher  \
# 0    50001                          68.8                                94.2
# 1    50002                          64.4                                99.3
# 2    50003                          60.7                                95.0
# 3    50005                          64.5                                93.5
# 4    50006                          54.9                                91.6
#
#    pct_Bachelors_degree_or_higher  Total_population    Male  Female  \
# 0                            31.8             749.0   331.0   418.0
# 1                            18.0            1359.0   687.0   672.0
# 2                            44.9            7872.0  3929.0  3943.0
# 3                            11.6            1060.0   462.0   598.0
# 4                            18.0            1596.0   821.0   775.0
#
#    Sex_ratio_(males_per_100_females)  Under_5_years  5_to_9_years  \
# ...

# %%
# census_combined4.info()

# %%
# Owner-occupied/Occupied_housing_units
# Renter-occupied/Occupied_housing_units  
census_combined4['pct_owner_occup_hous'] = census_combined4['Owner-occupied']/census_combined4['Occupied_housing_units']
census_combined4['pct_rent_occup_hous'] = census_combined4['Renter-occupied']/census_combined4['Occupied_housing_units']

# %%
# 25_to_34_years, Total_population 
census_combined4['pct_25_to_34_years'] = census_combined4['25_to_34_years']/census_combined4['Total_population']

# %%
census_combined4['pct_25_to_34_years'].describe()
# Out:
# count    932.000000
# mean       0.107327
# std        0.049329
# min        0.000000
# 25%        0.079137
# 50%        0.103979
# 75%        0.128933
# max        0.513514
# Name: pct_25_to_34_years, dtype: float64

# %%
census_combined4['Median_household_income_(dollars)'].describe()
# Out:
# count       934.000000
# mean      60835.738758
# std       18856.829535
# min           0.000000
# 25%       51446.750000
# 50%       59750.000000
# 75%       69393.000000
# max      162059.000000
# Name: Median_household_income_(dollars), dtype: float64

# %%
# census_combined4['population_density'] = census_combined4['Total_population'].div(census_combined4['Land_Area_(Sq._Miles)']).replace(np.inf, 0)

# %%
census_combined4['population_density'] = census_combined4['population_density'].round()

# %%
census_combined4['population_per_store_None'] = census_combined4['population_per_store_None'].round()

# %%
census_combined4.loc[census_combined4['Median_household_income_(dollars)'] > 75000,['Zip_Code','Median_household_income_(dollars)','population_density', 'population_per_store_None','Median_age_(years)','primary_city','county']].shape
# Out:
# (163, 7)

# %%
census_combined4.loc[census_combined4['Median_household_income_(dollars)'] > 75000,['Zip_Code','Median_household_income_(dollars)','population_density', 'population_per_store_None','Median_age_(years)','primary_city','county']]
# Out:
#     Zip_Code  Median_household_income_(dollars)  population_density  \
# 0      50001                            89773.0                32.0
# 2      50003                            88875.0                68.0
# 5      50007                           137917.0               103.0
# 7      50009                            80740.0               718.0
# 12     50021                            87938.0              1145.0
# 14     50023                            91974.0              1932.0
# 21     50033                           125000.0               103.0
# 23     50035                            97813.0               196.0
# 26     50039                            92500.0                23.0
# 30     50046                            76087.0                37.0
# 31     50047                            86117.0                97.0
# 37     50054                            77390.0                48.0
# 43     50061                           162059.0                80.0
# ...

# %%
census_combined4.loc[census_combined4['number_of_stores']==0,['Zip_Code','population_density','Total_population','Median_household_income_(dollars)','25_to_34_years','pct_25_to_34_years','land_area_sq_miles','Zip_Code','primary_city', 'county']]
# Out:
#     Zip_Code  population_density  Total_population  \
# 0      50001                32.0             749.0
# 5      50007               103.0             557.0
# 9      50012             13327.0            4578.0
# 16     50026                 8.0             461.0
# 17     50027                13.0             357.0
# 19     50029                14.0             537.0
# 20     50032              1325.0             563.0
# 22     50034                 7.0             420.0
# 25     50038                40.0             155.0
# 26     50039                23.0             472.0
# 27     50041               430.0              61.0
# 28     50042                 7.0             231.0
# 29     50044                20.0             956.0
# 34     50050                 9.0             692.0
# 35     50051                12.0             277.0
# 36     50052                 4.0              71.0
# 38     50055                19.0             979.0
# ...

# %%
census_combined4['land_area_sq_miles'].describe()
# Out:
# count    934.000000
# mean      59.998851
# std       46.722263
# min        0.068730
# 25%       28.516856
# 50%       49.299766
# 75%       82.702817
# max      338.451689
# Name: land_area_sq_miles, dtype: float64

# %%
census_combined4.population_per_store.describe()
# Out:
# count      932.000000
# mean       730.302575
# std        981.348097
# min          0.000000
# 25%          0.000000
# 50%        207.500000
# 75%       1272.750000
# max      12832.000000
# Name: population_per_store, dtype: float64

# %%
census_combined4['pop_25_to_34_yr_to_stores'] = census_combined4['25_to_34_years'].div(census_combined4['number_of_stores']).replace(np.inf, 0)

# %%
census_combined4['pop_25_to_34_yr_to_stores'].describe()
# Out:
# count     918.000000
# mean       85.429883
# std       126.411673
# min         0.000000
# 25%         0.000000
# 50%        33.812500
# 75%       141.357143
# max      1747.000000
# Name: pop_25_to_34_yr_to_stores, dtype: float64

# %%
census_combined4.population_density.describe()
# Out:
# count      934.000000
# mean       195.199143
# std        699.340013
# min          0.000000
# 25%         13.000000
# 50%         21.000000
# 75%         51.000000
# max      13327.000000
# Name: population_density, dtype: float64

# %%
# census_combined4.loc[census_combined4['Land_Area_(Sq._Miles)']==0,['Land_Area_(Sq._Miles)','Zip_Code','City','County','Total_population','population_per_store']]
