# %%
import pandas as pd
import numpy as np

# %%
cdtype ={'Zip_Code':str}

# %%
dp05_new = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\dp05_pop_gender_age_estimates.csv', dtype=cdtype,index_col=0)

# %%
dp04_new = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\dp04_new_housing.csv',dtype=cdtype,index_col=0)

# %%
dp03_new = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\income_in_2020_inflation_adjusted_dollars.csv',dtype=cdtype,index_col=0)

# %%
dp05_2015 = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\dp05_2015_pop_median_age_estimates.csv',dtype=cdtype,index_col=0)

# %%
square_miles_zip = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\Iowa  square miles  for each zip code copied.csv', encoding= 'unicode_escape',dtype={'ZIP Code':str})

# %%
dp05_new.head()
# Out:
#   Zip_Code     Total_population         Male         Female  \
# 0    50001                749.0        331.0          418.0
# 1    50002                1,359          687            672
# 2    50003                7,872        3,929          3,943
# 3    50005                1,060          462            598
# 4    50006                1,596          821            775
#
#           Sex_ratio_(males_per_100_females)         Under_5_years  \
# 0                                      79.2                  85.0
# 1                                     102.2                   101
# 2                                      99.6                   473
# 3                                      77.3                    44
# 4                                     105.9                    99
#
#           5_to_9_years         10_to_14_years         15_to_19_years  \
# 0                 48.0                   55.0                   57.0
# ...

# %%
dp04_new.head()
# Out:
#   Zip_Code  HOUSING_TENURE     Occupied_housing_units         Owner-occupied  \
# 0    50001  HOUSING_TENURE                        266                    233
# 1    50002  HOUSING_TENURE                        595                    438
# 2    50003  HOUSING_TENURE                      3,075                  2,429
# 3    50005  HOUSING_TENURE                        380                    307
# 4    50006  HOUSING_TENURE                        687                    470
#
#           Renter-occupied  \
# 0                      33
# 1                     157
# 2                     646
# 3                      73
# 4                     217
#
#           Average_household_size_of_owner-occupied_unit  \
# 0                                               2.73
# 1                                               2.38
# 2                                               2.66
# 3                                               2.93
# 4                                               2.27
#
# ...

# %%
dp03_new.head()
# Out:
#   Zip_Code  OCCUPATION     Civilian_employed_population_16_years_and_over  \
# 0    50001  OCCUPATION                                                357
# 1    50002  OCCUPATION                                                724
# 2    50003  OCCUPATION                                              4,232
# 3    50005  OCCUPATION                                                474
# 4    50006  OCCUPATION                                                859
#
#           Management,_business,_science,_and_arts_occupations  \
# 0                                                207
# 1                                                245
# 2                                              2,073
# 3                                                 59
# 4                                                268
#
#           Service_occupations         Sales_and_office_occupations  \
# 0                          24                                   64
# ...

# %%
dp05_2015.head()
# Out:
#   Zip_Code Total_population_2015 Median_age_2015 18_years_and_over_2015  \
# 0    50001                 734.0            33.8                  495.0
# 1    50002                 1,442              42                  1,094
# 2    50003                 7,109            42.5                  5,242
# 3    50005                 861.0            44.9                  641.0
# 4    50006                 1,556            44.8                  1,234
#
#   21_years_and_over_2015
# 0                  480.0
# 1                  1,070
# 2                  5,115
# 3                  618.0
# 4                  1,192

# %%
square_miles_zip.head()
# Out:
#   ZIP Code                              City                          County  \
# 0    50001              Ackworth, Sandyville                   Warren County
# 1    50002                             Adair    Adair County, Guthrie County
# 2    50003  Adel, De Soto, Van Meter, Waukee                   Dallas County
# 3    50005                            Albion                 Marshall County
# 4    50006           Alden, Buckeye, Popejoy  Franklin County, Hardin County
#
#   Land Area (Sq. Meters)  Land Area (Sq. Miles)  Land Area (Sq. Kilometers)
# 0             62,132,100                     24                          62
# 1            279,020,000                    108                         279
# 2            296,262,000                    114                         296
# 3             69,351,800                     27                          69
# 4            317,609,000                    123                         318

# %%
square_miles_zip.columns = square_miles_zip.columns.str.replace(' ','_')

# %%
square_miles_zip.head()
# Out:
#   ZIP_Code                              City                          County  \
# 0    50001              Ackworth, Sandyville                   Warren County
# 1    50002                             Adair    Adair County, Guthrie County
# 2    50003  Adel, De Soto, Van Meter, Waukee                   Dallas County
# 3    50005                            Albion                 Marshall County
# 4    50006           Alden, Buckeye, Popejoy  Franklin County, Hardin County
#
#   Land_Area_(Sq._Meters)  Land_Area_(Sq._Miles)  Land_Area_(Sq._Kilometers)
# 0             62,132,100                     24                          62
# 1            279,020,000                    108                         279
# 2            296,262,000                    114                         296
# 3             69,351,800                     27                          69
# 4            317,609,000                    123                         318

# %%
square_miles_zip.shape
# Out:
# (918, 6)

# %%
dp05_2015.shape
# Out:
# (935, 5)

# %%
dfs = [ dp05_new, dp05_2015, dp03_new, dp04_new] 
census = pd.concat([df.set_index('Zip_Code') for df in dfs], axis=1)

# %%
census = census.reset_index()

# %%
census.head()
# Out:
#   Zip_Code     Total_population         Male         Female  \
# 0    50001                749.0        331.0          418.0
# 1    50002                1,359          687            672
# 2    50003                7,872        3,929          3,943
# 3    50005                1,060          462            598
# 4    50006                1,596          821            775
#
#           Sex_ratio_(males_per_100_females)         Under_5_years  \
# 0                                      79.2                  85.0
# 1                                     102.2                   101
# 2                                      99.6                   473
# 3                                      77.3                    44
# 4                                     105.9                    99
#
#           5_to_9_years         10_to_14_years         15_to_19_years  \
# 0                 48.0                   55.0                   57.0
# ...

# %%
square_miles_zip.head(2)
# Out:
#   ZIP_Code                  City                        County  \
# 0    50001  Ackworth, Sandyville                 Warren County
# 1    50002                 Adair  Adair County, Guthrie County
#
#   Land_Area_(Sq._Meters)  Land_Area_(Sq._Miles)  Land_Area_(Sq._Kilometers)
# 0             62,132,100                     24                          62
# 1            279,020,000                    108                         279

# %% [raw]
# # Iowa Land area in square miles, 2010 by County
# County	Value
# Adair	569.27
# Adams	423.44
# Allamakee	639.08
# Appanoose	497.29
# Audubon	442.96
# Benton	716.27
# Black Hawk	565.77
# Boone	571.57
# Bremer	435.48
# Buchanan	571.02
# Buena Vista	574.92
# Butler	580.13
# Calhoun	569.97
# Carroll	569.44
# Cass	564.27
# Cedar	579.44
# Cerro Gordo	568.31
# Cherokee	576.91
# Chickasaw	504.38
# Clarke	431.17
# Clay	567.24
# Clayton	778.54
# Clinton	694.92
# Crawford	714.19
# Dallas	588.45
# Davis	502.19
# Decatur	531.88
# Delaware	577.76
# Des Moines	416.12
# Dickinson	380.61
# Dubuque	608.31
# Emmet	395.88
# Fayette	730.81
# Floyd	500.63
# Franklin	581.97
# Fremont	511.15
# Greene	569.57
# Grundy	501.86
# Guthrie	590.62
# Hamilton	576.75
# Hancock	571.01
# Hardin	569.31
# Harrison	696.85
# Henry	434.33
# Howard	473.25
# Humboldt	434.35
# Ida	431.51
# Iowa	586.46
# Jackson	636.04
# Jasper	730.42
# Jefferson	435.51
# Johnson	614.04
# Jones	575.62
# Keokuk	579.18
# Kossuth	972.72
# Lee	517.52
# Linn	716.88
# Louisa	401.77
# Lucas	430.59
# Lyon	587.65
# Madison	561.01
# Mahaska	570.86
# Marion	554.53
# Marshall	572.50
# Mills	437.44
# Mitchell	469.13
# Monona	694.07
# Monroe	433.72
# Montgomery	424.10
# Muscatine	437.47
# Osceola	398.68
# Page	534.94
# Palo Alto	563.84
# Plymouth	862.89
# Pocahontas	577.24
# Polk	573.80
# Pottawattamie	950.28
# Poweshiek	584.93
# Ringgold	535.50
# Sac	575.01
# Scott	458.09
# Shelby	590.78
# Sioux	768.33
# Story	572.82
# Tama	721.01
# Taylor	531.90
# Union	423.65
# Van Buren	484.79
# Wapello	431.83
# Warren	569.83
# Washington	568.84
# Wayne	525.44
# Webster	715.62
# Winnebago	400.49
# Winneshiek	689.87
# Woodbury	872.83
# Worth	400.12
# Wright	580.42

# %%
census.shape
# Out:
# (935, 66)

# %%
cols = list(census.columns)

# %%
new_cols = [col.strip() for col in cols]

# %%
census.columns = new_cols

# %%
pd.set_option('display.max_columns', None)
census.head()
# Out:
#   Zip_Code Total_population   Male Female Sex_ratio_(males_per_100_females)  \
# 0    50001            749.0  331.0  418.0                              79.2
# 1    50002            1,359    687    672                             102.2
# 2    50003            7,872  3,929  3,943                              99.6
# 3    50005            1,060    462    598                              77.3
# 4    50006            1,596    821    775                             105.9
#
#   Under_5_years 5_to_9_years 10_to_14_years 15_to_19_years 20_to_24_years  \
# 0          85.0         48.0           55.0           57.0           39.0
# 1           101          101             61             50             43
# 2           473          661            608            371            385
# 3            44           98             39             66             18
# 4            99           92            130             60             43
#
# ...

# %%
census.columns
# Out:
# Index(['Zip_Code', 'Total_population', 'Male', 'Female',
#        'Sex_ratio_(males_per_100_females)', 'Under_5_years', '5_to_9_years',
#        '10_to_14_years', '15_to_19_years', '20_to_24_years', '25_to_34_years',
#        '35_to_44_years', '45_to_54_years', '55_to_59_years', '60_to_64_years',
#        '65_to_74_years', '75_to_84_years', '85_years_and_over',
#        'Median_age_(years)', 'Under_18_years', '16_years_and_over',
#        '18_years_and_over', '21_years_and_over', '62_years_and_over',
#        '65_years_and_over', 'Total_population_2015', 'Median_age_2015',
#        '18_years_and_over_2015', '21_years_and_over_2015', 'OCCUPATION',
#        'Civilian_employed_population_16_years_and_over',
#        'Management,_business,_science,_and_arts_occupations',
#        'Service_occupations', 'Sales_and_office_occupations',
#        'Natural_resources,_construction,_and_maintenance_occupations',
#        'Production,_transportation,_and_material_moving_occupations',
# ...

# %%
census.rename({'Median_(dollars)':'Median_Home_Market_Value'},axis=1, inplace=True)

# %%
census.head(2)
# Out:
#   Zip_Code Total_population   Male Female Sex_ratio_(males_per_100_females)  \
# 0    50001            749.0  331.0  418.0                              79.2
# 1    50002            1,359    687    672                             102.2
#
#   Under_5_years 5_to_9_years 10_to_14_years 15_to_19_years 20_to_24_years  \
# 0          85.0         48.0           55.0           57.0           39.0
# 1           101          101             61             50             43
#
#   25_to_34_years 35_to_44_years 45_to_54_years 55_to_59_years 60_to_64_years  \
# 0           43.0          120.0           77.0           66.0           68.0
# 1            172            119            210            139            124
#
#   65_to_74_years 75_to_84_years 85_years_and_over Median_age_(years)  \
# 0           57.0           34.0               0.0               39.3
# 1            117             93                29               47.7
#
# ...

# %%
census_combined = census.merge(square_miles_zip, how='left', left_on='Zip_Code', right_on='ZIP_Code' )

# %%
census_combined.head(2)
# Out:
#   Zip_Code Total_population   Male Female Sex_ratio_(males_per_100_females)  \
# 0    50001            749.0  331.0  418.0                              79.2
# 1    50002            1,359    687    672                             102.2
#
#   Under_5_years 5_to_9_years 10_to_14_years 15_to_19_years 20_to_24_years  \
# 0          85.0         48.0           55.0           57.0           39.0
# 1           101          101             61             50             43
#
#   25_to_34_years 35_to_44_years 45_to_54_years 55_to_59_years 60_to_64_years  \
# 0           43.0          120.0           77.0           66.0           68.0
# 1            172            119            210            139            124
#
#   65_to_74_years 75_to_84_years 85_years_and_over Median_age_(years)  \
# 0           57.0           34.0               0.0               39.3
# 1            117             93                29               47.7
#
# ...

# %%
np.sum(census_combined.County.isna())
# Out:
# 17

# %%
census_combined[census_combined.County.isna()]
# Out:
#     Zip_Code Total_population   Male Female Sex_ratio_(males_per_100_females)  \
# 21     50032            563.0  113.0  450.0                              25.1
# 41     50057            288.0  163.0  125.0                             130.4
# 74     50117            138.0   64.0   74.0                              86.5
# 83     50127                0      0      0                                 -
# 134    50214            832.0  374.0  458.0                              81.7
# 170    50256            573.0  247.0  326.0                              75.8
# 269    50521             77.0   47.0   30.0                             156.7
# 340    50612            331.0  146.0  185.0                              78.9
# 377    50664             35.0   20.0   15.0                             133.3
# 676    52140            474.0  274.0  200.0                             137.0
# 816    52543              540    339    201                             168.7
# ...

# %% [raw]
# The Shamrock Spirits
#
# 1204 Water St, Alden, IA, 50006
# (515) 859-3086

# %%
pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', None)

census.loc[census.Zip_Code=='50006',:].T  #shamrocks
# Out:
#                                                                  4
# Zip_Code                                                     50006
# Total_population                                             1,596
# Male                                                           821
# Female                                                         775
# Sex_ratio_(males_per_100_females)                            105.9
# Under_5_years                                                   99
# 5_to_9_years                                                    92
# 10_to_14_years                                                 130
# 15_to_19_years                                                  60
# 20_to_24_years                                                  43
# 25_to_34_years                                                 219
# 35_to_44_years                                                 235
# 45_to_54_years                                                 195
# ...

# %%
# 50314
pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', None)

census.loc[census.Zip_Code=='50314',:].T  #Central City Liquor, Inc.
# Out:
#                                                                193
# Zip_Code                                                     50314
# Total_population                                            11,231
# Male                                                         5,377
# Female                                                       5,854
# Sex_ratio_(males_per_100_females)                             91.9
# Under_5_years                                                  911
# 5_to_9_years                                                   805
# 10_to_14_years                                                 899
# 15_to_19_years                                                 941
# 20_to_24_years                                                 918
# 25_to_34_years                                               2,005
# 35_to_44_years                                               1,470
# 45_to_54_years                                               1,252
# ...

# %%
50314
# Out:
# 50314

# %%
#Dyno's Wine and Spirits / Storm Lake 	50588

census.loc[census.Zip_Code=='50588',:]
# Out:
#     Zip_Code Total_population   Male Female Sex_ratio_(males_per_100_females)  \
# 322    50588           12,695  6,346  6,349                             100.0
#
#     Under_5_years 5_to_9_years 10_to_14_years 15_to_19_years 20_to_24_years  \
# 322           964        1,005            783          1,195          1,208
#
#     25_to_34_years 35_to_44_years 45_to_54_years 55_to_59_years  \
# 322          1,676          1,511          1,156            988
#
#     60_to_64_years 65_to_74_years 75_to_84_years 85_years_and_over  \
# 322            642            914            323               330
#
#     Median_age_(years) Under_18_years 16_years_and_over 18_years_and_over  \
# 322               31.6          3,332             9,810             9,363
#
#     21_years_and_over 62_years_and_over 65_years_and_over  \
# 322             8,549             1,982             1,567
#
#     Total_population_2015 Median_age_2015 18_years_and_over_2015  \
# ...

# %%
census.loc[census.Zip_Code=='50574',:] #Dyno's Wine and Spirits / Pocahontas
# Out:
#     Zip_Code Total_population Male Female Sex_ratio_(males_per_100_females)  \
# 311    50574            1,946  903  1,043                              86.6
#
#     Under_5_years 5_to_9_years 10_to_14_years 15_to_19_years 20_to_24_years  \
# 311           124          102             66             71            182
#
#     25_to_34_years 35_to_44_years 45_to_54_years 55_to_59_years  \
# 311            191             61            190            219
#
#     60_to_64_years 65_to_74_years 75_to_84_years 85_years_and_over  \
# 311            250            206            210                74
#
#     Median_age_(years) Under_18_years 16_years_and_over 18_years_and_over  \
# 311               54.5            346             1,628             1,600
#
#     21_years_and_over 62_years_and_over 65_years_and_over  \
# 311             1,564               643               490
#
#     Total_population_2015 Median_age_2015 18_years_and_over_2015  \
# ...

# %%
square_miles_zip.reset_index()
# Out:
#      index ZIP_Code                                               City  \
# 0        0    50001                               Ackworth, Sandyville
# 1        1    50002                                              Adair
# 2        2    50003                   Adel, De Soto, Van Meter, Waukee
# 3        3    50005                                             Albion
# 4        4    50006                            Alden, Buckeye, Popejoy
# 5        5    50007                                            Alleman
# 6        6    50008                                           Allerton
# 7        7    50009                     Altoona, Bondurant, Des Moines
# 8        8    50010                                               Ames
# 9        9    50011                                               Ames
# 10      10    50012                                               Ames
# 11      11    50014                                               Ames
# ...

# %%
square_miles_zip.loc[square_miles_zip.ZIP_Code=='50588',:]
# Out:
#     ZIP_Code                             City              County  \
# 315    50588  Lakeside, Storm Lake, Truesdale  Buena Vista County
#
#     Land_Area_(Sq._Meters)  Land_Area_(Sq._Miles)  Land_Area_(Sq._Kilometers)
# 315            356,362,000                    138                         356

# %%
square_miles_zip.loc[square_miles_zip.ZIP_Code=='50006',:] #shamrocks
# Out:
#   ZIP_Code                     City                          County  \
# 4    50006  Alden, Buckeye, Popejoy  Franklin County, Hardin County
#
#   Land_Area_(Sq._Meters)  Land_Area_(Sq._Miles)  Land_Area_(Sq._Kilometers)
# 4            317,609,000                    123                         318
