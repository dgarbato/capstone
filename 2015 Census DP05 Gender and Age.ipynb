# %%
import pandas as pd
import numpy as np

# %%
from missing_columns_pd import miss_cols

# %%
dp05 = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\Iowa DP05 2015 ACSDP5Y2015.DP05-2022-04-13_edited.csv')

# %%
dp05.head()
# Out:
#        Label (Grouping)  ZCTA5 50001!!Estimate ZCTA5 50001!!Margin of Error  \
# 0           SEX AND AGE                    NaN                          NaN
# 1      Total population                  734.0                         ±249
# 2                  Male                  383.0                         ±142
# 3                Female                  351.0                         ±117
# 4         Under 5 years                   31.0                          ±25
#
#   ZCTA5 50001!!Percent ZCTA5 50001!!Percent Margin of Error  \
# 0                  NaN                                  NaN
# 1                  734                                  (X)
# 2               52.20%                                 ±4.9
# 3               47.80%                                 ±4.9
# 4                4.20%                                 ±3.0
#
#   ZCTA5 50002!!Estimate ZCTA5 50002!!Margin of Error ZCTA5 50002!!Percent  \
# ...

# %%
cols = list(dp05.columns)
# cols

# %%
new_cols = list(filter(lambda col: "Estimate" in col,cols)) 
# new_cols.append('Label (Grouping)')
new_cols = ['Label (Grouping)'] + new_cols
# new_cols

# %%
dp05_new = dp05[new_cols]

# %%
pd.set_option('display.max_rows', 95)
dp05_new.head(95)
# Out:
#                                      Label (Grouping)  ZCTA5 50001!!Estimate  \
# 0                                         SEX AND AGE                    NaN
# 1                                    Total population                  734.0
# 2                                                Male                  383.0
# 3                                              Female                  351.0
# 4                                       Under 5 years                   31.0
# 5                                        5 to 9 years                  108.0
# 6                                      10 to 14 years                   71.0
# 7                                      15 to 19 years                   44.0
# 8                                      20 to 24 years                   18.0
# 9                                      25 to 34 years                  121.0
# 10                                     35 to 44 years                   58.0
# ...

# %%
dp05_new = dp05_new.drop([0])

# %%
dp05_new
# Out:
#                                      Label (Grouping)  ZCTA5 50001!!Estimate  \
# 1                                    Total population                  734.0
# 2                                                Male                  383.0
# 3                                              Female                  351.0
# 4                                       Under 5 years                   31.0
# 5                                        5 to 9 years                  108.0
# 6                                      10 to 14 years                   71.0
# 7                                      15 to 19 years                   44.0
# 8                                      20 to 24 years                   18.0
# 9                                      25 to 34 years                  121.0
# 10                                     35 to 44 years                   58.0
# 11                                     45 to 54 years                  107.0
# ...

# %%
df1 = dp05_new.iloc[[0]]

# %%
df2 = dp05_new.iloc[[16]]

# %%
df3 = dp05_new.iloc[[17]]

# %%
df4 = dp05_new.iloc[[18]]

# %%
df05_2015 = pd.concat([df1, df2, df3, df4])
df05_2015.head()
# Out:
#           Label (Grouping)  ZCTA5 50001!!Estimate ZCTA5 50002!!Estimate  \
# 1         Total population                  734.0                 1,442
# 17      Median age (years)                   33.8                    42
# 18       18 years and over                  495.0                 1,094
# 19       21 years and over                  480.0                 1,070
#
#    ZCTA5 50003!!Estimate  ZCTA5 50005!!Estimate ZCTA5 50006!!Estimate  \
# 1                  7,109                  861.0                 1,556
# 17                  42.5                   44.9                  44.8
# 18                 5,242                  641.0                 1,234
# 19                 5,115                  618.0                 1,192
#
#     ZCTA5 50007!!Estimate  ZCTA5 50008!!Estimate ZCTA5 50009!!Estimate  \
# 1                   598.0                  945.0                17,561
# 17                   41.5                   37.9                  34.9
# ...

# %%
# dp05_new =  dp05_new.drop(range(25,94))

# %%
cols = list(df05_2015.columns)
cols
# Out:
# ['Label (Grouping)',
#  'ZCTA5 50001!!Estimate',
#  'ZCTA5 50002!!Estimate',
#  'ZCTA5 50003!!Estimate',
#  'ZCTA5 50005!!Estimate',
#  'ZCTA5 50006!!Estimate',
#  'ZCTA5 50007!!Estimate',
#  'ZCTA5 50008!!Estimate',
#  'ZCTA5 50009!!Estimate',
#  'ZCTA5 50010!!Estimate',
#  'ZCTA5 50011!!Estimate',
#  'ZCTA5 50012!!Estimate',
#  'ZCTA5 50014!!Estimate',
#  'ZCTA5 50020!!Estimate',
#  'ZCTA5 50021!!Estimate',
#  'ZCTA5 50022!!Estimate',
#  'ZCTA5 50023!!Estimate',
#  'ZCTA5 50025!!Estimate',
#  'ZCTA5 50026!!Estimate',
#  'ZCTA5 50027!!Estimate',
#  'ZCTA5 50028!!Estimate',
#  'ZCTA5 50029!!Estimate',
#  'ZCTA5 50032!!Estimate',
#  'ZCTA5 50033!!Estimate',
#  'ZCTA5 50034!!Estimate',
#  'ZCTA5 50035!!Estimate',
#  'ZCTA5 50036!!Estimate',
#  'ZCTA5 50038!!Estimate',
#  'ZCTA5 50039!!Estimate',
#  'ZCTA5 50041!!Estimate',
#  'ZCTA5 50042!!Estimate',
#  'ZCTA5 50044!!Estimate',
#  'ZCTA5 50046!!Estimate',
#  'ZCTA5 50047!!Estimate',
#  'ZCTA5 50048!!Estimate',
# ...

# %%
L = 'ZCTA5 50001!!Estimate'.split()
L2 = L[1]
L2
L3 = L2.split('!!')
zip = L3[0]
zip
# Out:
# '50001'

# %%
def get_zip(string):
    L = string.split()
    L2 = L[1]
    L2
    L3 = L2.split('!!')
    zip = L3[0]
    return(zip)

# %%
get_zip('ZCTA5 50001!!Estimate')
# Out:
# '50001'

# %%
new_cols = ['Label (Grouping)' if 'Label (Grouping)' in col_name   else get_zip(col_name) for col_name in cols]
new_cols
# Out:
# ['Label (Grouping)',
#  '50001',
#  '50002',
#  '50003',
#  '50005',
#  '50006',
#  '50007',
#  '50008',
#  '50009',
#  '50010',
#  '50011',
#  '50012',
#  '50014',
#  '50020',
#  '50021',
#  '50022',
#  '50023',
#  '50025',
#  '50026',
#  '50027',
#  '50028',
#  '50029',
#  '50032',
#  '50033',
#  '50034',
#  '50035',
#  '50036',
#  '50038',
#  '50039',
#  '50041',
#  '50042',
#  '50044',
#  '50046',
#  '50047',
#  '50048',
#  '50049',
#  '50050',
#  '50051',
#  '50052',
#  '50054',
#  '50055',
#  '50056',
#  '50057',
#  '50058',
#  '50060',
#  '50061',
#  '50062',
#  '50063',
#  '50064',
#  '50065',
#  '50066',
#  '50067',
#  '50068',
#  '50069',
#  '50070',
#  '50071',
#  '50072',
#  '50073',
#  '50074',
#  '50075',
#  '50076',
#  '50078',
#  '50101',
#  '50102',
#  '50103',
#  '50104',
#  '50105',
#  '50106',
#  '50107',
#  '50108',
#  '50109',
#  '50111',
#  '50112',
#  '50115',
#  '50116',
#  '50117',
#  '50118',
#  '50119',
#  '50120',
#  '50122',
#  '50123',
#  '50124',
# ...

# %%
new_cols

# %% [markdown]
# assign new column names

# %%
# df.columns=['com', 'year', 'production_Moz']
df05_2015.columns = new_cols

# %%
df05_2015.head()
# Out:
#           Label (Grouping)  50001  50002  50003  50005  50006  50007  50008  \
# 1         Total population  734.0  1,442  7,109  861.0  1,556  598.0  945.0
# 17      Median age (years)   33.8     42   42.5   44.9   44.8   41.5   37.9
# 18       18 years and over  495.0  1,094  5,242  641.0  1,234  415.0  714.0
# 19       21 years and over  480.0  1,070  5,115  618.0  1,192  401.0  697.0
#
#      50009   50010  ...  52776  52777  52778  52801   52802   52803   52804  \
# 1   17,561  31,870  ...  4,553  1,298  4,207  945.0  10,436  22,858  27,218
# 17    34.9    29.5  ...   34.7   44.6   39.6   34.4    36.6    33.3    36.9
# 18  12,757  26,216  ...  3,261    980  3,207  919.0   7,792  17,531  21,152
# 19  12,140  23,711  ...  3,198    947  2,993  895.0   7,363  16,477  19,466
#
#      52806   52807  56027
# 1   28,268  14,770  903.0
# 17      35    36.5   42.4
# 18  21,070  11,307  672.0
# 19  20,126  10,904  661.0
#
# [4 rows x 936 columns]

# %% [markdown]
# transpose data frame

# %%
df05_2015 = df05_2015.set_index('Label (Grouping)').T

# %%
df05_2015.head()
# Out:
# Label (Grouping)     Total population     Median age (years)  \
# 50001                           734.0                   33.8
# 50002                           1,442                     42
# 50003                           7,109                   42.5
# 50005                           861.0                   44.9
# 50006                           1,556                   44.8
#
# Label (Grouping)     18 years and over     21 years and over
# 50001                            495.0                 480.0
# 50002                            1,094                 1,070
# 50003                            5,242                 5,115
# 50005                            641.0                 618.0
# 50006                            1,234                 1,192

# %%
df05_2015.columns = df05_2015.columns.str.replace(' ','_')

# %%
df05_2015 = df05_2015.reset_index()

# %%
df05_2015.head()
# Out:
# Label (Grouping)  index     Total_population     Median_age_(years)  \
# 0                 50001                734.0                   33.8
# 1                 50002                1,442                     42
# 2                 50003                7,109                   42.5
# 3                 50005                861.0                   44.9
# 4                 50006                1,556                   44.8
#
# Label (Grouping)     18_years_and_over     21_years_and_over
# 0                                495.0                 480.0
# 1                                1,094                 1,070
# 2                                5,242                 5,115
# 3                                641.0                 618.0
# 4                                1,234                 1,192

# %%
new_cols=['Zip_Code', 'Total_population_2015','Median_age_2015', '18_years_and_over_2015','21_years_and_over_2015']

# %%
dp05_2015 = df05_2015.copy()

# %%
dp05_2015.columns = new_cols

# %%
dp05_2015
# Out:
#     Zip_Code Total_population_2015 Median_age_2015 18_years_and_over_2015  \
# 0      50001                 734.0            33.8                  495.0
# 1      50002                 1,442              42                  1,094
# 2      50003                 7,109            42.5                  5,242
# 3      50005                 861.0            44.9                  641.0
# 4      50006                 1,556            44.8                  1,234
# ..       ...                   ...             ...                    ...
# 930    52803                22,858            33.3                 17,531
# 931    52804                27,218            36.9                 21,152
# 932    52806                28,268              35                 21,070
# 933    52807                14,770            36.5                 11,307
# 934    56027                 903.0            42.4                  672.0
#
#     21_years_and_over_2015
# 0                    480.0
# ...

# %%
miss_cols(dp05_2015)
# Out:
# []

# %%
dp05_2015.to_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\dp05_2015_pop_median_age_estimates.csv')
