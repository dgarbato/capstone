# %%
from dask import dataframe as dd

# %%
from dask import delayed as delayed

# %%
import pandas as pd
import numpy as np

# %%
dict_dtypes ={'Invoice/Item Number':str,
 'Date':str,
 'Store Number':str,
 'Store Name':str,
 'Address':str,
 'City':str,
 'Zip Code':str,
 'Store Location':str,
 'County Number':str,
 'County':str,
 'Category':str,
 'Category Name':str,
 'Vendor Number':str,
 'Vendor Name':str,
 'Item Number':str,
 'Item Description':str,
 'Pack':int,
 'Bottle Volume (ml)':int,
 'State Bottle Cost':float,
 'State Bottle Retail':float,
 'Bottles Sold':int,
 'Sale (Dollars)':float,
 'Volume Sold (Liters)':float,
 'Volume Sold (Gallons)':float}

# %%
df_17_22 = dd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2017_to_2022.csv', dtype= dict_dtypes)

# %%
pd.set_option('display.max_columns', None)
df_17_22.head()
# Out:
#   Invoice/Item Number        Date Store Number  \
# 0     INV-16608300016  12/28/2018         4932
# 1     INV-16607200030  12/28/2018         5656
# 2     INV-16607600007  12/28/2018         2106
# 3     INV-16607800025  12/28/2018         5155
# 4     INV-16607100031  12/28/2018         3540
#
#                         Store Name               Address         City  \
# 0                     B and B West        3105 Hudson Rd  Cedar Falls
# 1           Cody Mart Gas & Liquor        1220 N Cody Rd    Le Claire
# 2      Hillstreet News and Tobacco          2217 College  Cedar Falls
# 3      New Star  /  Ansborough Ave  1459, Ansborough Ave     Waterloo
# 4  Super Target T-0533 / Davenport       5225 Elmore Ave    Davenport
#
#   Zip Code                Store Location County Number      County Category  \
# 0    50613  POINT (-92.465838 42.509248)             7  BLACK HAWK  1031100
# 1    52753   POINT (-90.34429 41.611036)            82       SCOTT  1081600
# 2    50613  POINT (-92.455796 42.517182)             7  BLACK HAWK  1032100
# 3    50701  POINT (-92.376863 42.493091)             7  BLACK HAWK  1031100
# 4    52807  POINT (-90.528585 41.573196)            82       SCOTT  1701100
#
#                     Category Name Vendor Number               Vendor Name  \
# 0                 American Vodkas           300  McCormick Distilling Co.
# 1                 Whiskey Liqueur           421      SAZERAC COMPANY  INC
# 2                 Imported Vodkas           035           BACARDI USA INC
# 3                 American Vodkas           300  McCormick Distilling Co.
# 4  Temporary & Specialty Packages           420         MOET HENNESSY USA
#
#   Item Number          Item Description  Pack  Bottle Volume (ml)  \
# 0       36908       Mccormick Vodka Pet     6                1750
# 1       86881     Southern Comfort Mini    10                 600
# 2       34433                Grey Goose    12                 750
# 3       36904       Mccormick Vodka Pet    24                 375
# 4        1258  Glenmorangie Taster Pack     6                 100
#
#    State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 0               7.47                11.21             6           67.26
# 1               5.65                 8.48            10           84.80
# 2              18.49                27.74            12          332.88
# 3               1.80                 2.70            24           64.80
# 4              14.99                22.49             6          134.94
#
#    Volume Sold (Liters)  Volume Sold (Gallons)    dd_date  volume
# 0                  10.5                   2.77 2018-12-28   1.750
# 1                   6.0                   1.58 2018-12-28   0.600
# 2                   9.0                   2.37 2018-12-28   0.750
# 3                   9.0                   2.37 2018-12-28   0.375
# 4                   0.6                   0.15 2018-12-28   0.100

# %%
df_17_22['dd_date'] = dd.to_datetime(df_17_22['Date'])

# %%
# create volume in liters
# df_17_22['volume'] = df_17_22['Bottle Volume (ml)']/1000

# %%
df_17_22['year'] = pd.Series([int(dt[-4:]) for dt in df_17_22['Date'] ])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2812/3091833429.py in <module>
# ----> 1 df_17_22['year'] = pd.Series([int(dt[-4:]) for dt in df_17_22['Date'] ])
#
# ~\anaconda3_reinstall\lib\site-packages\dask\dataframe\core.py in __setitem__(self, key, value)
#    4119             raise NotImplementedError(f"Item assignment with {type(key)} not supported")
#    4120         else:
# -> 4121             df = self.assign(**{key: value})
#    4122
#    4123         self.dask = df.dask
#
# ~\anaconda3_reinstall\lib\site-packages\dask\dataframe\core.py in assign(self, **kwargs)
#    4442                 **_extract_meta({k: kwargs[k]}, nonempty=True)
#    4443             )
# -> 4444             data = elemwise(methods.assign, data, *pairs, meta=df2)
#    4445
#    4446         return data
#
# ~\anaconda3_reinstall\lib\site-packages\dask\dataframe\core.py in elemwise(op, *args, **kwargs)
#    5377     from .multi import _maybe_align_partitions
#    5378
# -> 5379     args = _maybe_align_partitions(args)
#    5380     dasks = [arg for arg in args if isinstance(arg, (_Frame, Scalar, Array))]
#    5381     dfs = [df for df in dasks if isinstance(df, _Frame)]
#
# ~\anaconda3_reinstall\lib\site-packages\dask\dataframe\multi.py in _maybe_align_partitions(args)
#     166     divisions = dfs[0].divisions
#     167     if not all(df.divisions == divisions for df in dfs):
# --> 168         dfs2 = iter(align_partitions(*dfs)[0])
#     169         return [a if not isinstance(a, _Frame) else next(dfs2) for a in args]
#     170     return args
#
# ~\anaconda3_reinstall\lib\site-packages\dask\dataframe\multi.py in align_partitions(*dfs)
#     120         raise ValueError("dfs contains no DataFrame and Series")
#     121     if not all(df.known_divisions for df in dfs1):
# --> 122         raise ValueError(
#     123             "Not all divisions are known, can't align "
#     124             "partitions. Please use `set_index` "
#
# ValueError: Not all divisions are known, can't align partitions. Please use `set_index` to set the index.

# %% [markdown]
#  master dataframe called transactions, which records the vendor number, store number, product (item number),
#  transaction date, bottles sold, volume (either in gallons or in liters), sales amount.

# %%
df_transactions = df_17_22[['Vendor Number', 'Store Number','Item Number', 'Date','dd_date', 'Volume Sold (Liters)', 'Bottles Sold','Sale (Dollars)','State Bottle Cost','State Bottle Retail']]

# %%
df_transactions.compute().to_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\df_transactions.csv')

# %%
df_17_22['dd_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_prod1 = df_17_22.sort_values(by=['dd_date']).drop_duplicates(['Item Number'],keep='last')

# %%
df_prod1.shape[0]
# Out:
# Delayed('int-f1e0c3c6-b229-41a0-8819-461f1d582fa7')

# %%
df_products = df_prod1[['Item Number', 'Item Description', 'Date', 'dd_date']]

# %%
df_products.compute().to_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\df_products.csv')

# %%
type(df_prod1)
df_prod1.head()
# Out:
#        Invoice/Item Number        Date Store Number  \
# 68666      INV-02503200001  01/03/2017         2590
# 75823      INV-02529800017  01/04/2017         5237
# 105163     INV-02540000018  01/04/2017         5351
# 92800      INV-02542600017  01/04/2017         4025
# 87490      INV-02561300003  01/05/2017         2190
#
#                                  Store Name               Address  \
# 68666   Hy-Vee Food Store #5 / Cedar Rapids  3235 Oakland Road NE
# 75823         World Liquor & Tobacco + Vape        606, N 15th St
# 105163                      Downtown Liquor          1203 5th St.
# 92800               Karam Kaur Khasriya Llc           702 13th St
# 87490             Central City Liquor, Inc.          1460 2ND AVE
#
#                 City Zip Code                Store Location County Number  \
# 68666   Cedar Rapids    52402  POINT (-91.658105 42.010971)            57
# 75823     Fort Dodge    50501   POINT (-94.17795 42.512182)            48
# 105163    Sioux City    51101  POINT (-96.394671 42.495324)            97
# 92800   Belle Plaine    52208  POINT (-92.277759 41.897052)             6
# 87490     Des Moines    50314   POINT (-93.619787 41.60566)            77
#
#           County  ...                     Item Description Pack  \
# 68666       LINN  ...                 Galliano L'Autentico   12
# 75823       Iowa  ...  Hennessy Master Blender's Selection   12
# 105163  WOODBURY  ...                         Master's Gin    6
# 92800     BENTON  ...                        Indian Summer    6
# 87490       POLK  ...          Merrylegs Genever Style Gin   12
#
#        Bottle Volume (ml) State Bottle Cost State Bottle Retail Bottles Sold  \
# 68666                 750             19.05               28.58           12
# 75823                 375             22.49               33.74            1
# 105163                750             17.17               25.76            1
# 92800                 750             15.85               23.78            1
# 87490                 750             19.00               28.50           24
#
#         Sale (Dollars)  Volume Sold (Liters)  Volume Sold (Gallons)    dd_date
# 68666           342.96                  9.00                   2.38 2017-01-03
# 75823            33.74                  0.38                   0.10 2017-01-04
# 105163           25.76                  0.75                   0.20 2017-01-04
# 92800            23.78                  0.75                   0.20 2017-01-04
# 87490           684.00                 18.00                   4.76 2017-01-05
#
# [5 rows x 25 columns]

# %%
df_prod1.tail(5)
# Out:
#        Invoice/Item Number        Date Store Number  \
# 169624     INV-45116500001  02/28/2022         5651
# 169625     INV-45125300017  02/28/2022         2647
# 181634     INV-45133000029  02/28/2022         5663
# 181671     INV-45123100095  02/28/2022         2633
# 181727     INV-45123700063  02/28/2022         2527
# ...                    ...         ...          ...
# 181528     INV-45126300015  02/28/2022         5462
# 169694     INV-45118700017  02/28/2022         2625
# 169696     INV-45130100002  02/28/2022         3806
# 169670     INV-45123100088  02/28/2022         2633
# 189106     INV-45147800008  02/28/2022         5620
#
#                                      Store Name                Address  \
# 169624       Super Quick Mart / Windsor Heights        7690 Hickman Rd
# 169625                 Hy-Vee #7 / Cedar Rapids       5050 Edgewood Rd
# 181634      Lake View Redemption & Liquor Store             502 5th St
# 181671             Hy-Vee #3 / BDI / Des Moines        3221 SE 14th St
# 181727        Hy-Vee Food Store #5 / Des Moines   1107 SE Army Post Rd
# ...                                         ...                    ...
# 181528            7Star Liquor & Tobacco Outlet           502 E Ave NW
# 169694     Hy-Vee Wine & Spirits #2 / Davenport     3301 W Kimberly Rd
# 169696                Target Store T-1901 / Wdm  5405 Mills Civic Pkwy
# 169670             Hy-Vee #3 / BDI / Des Moines        3221 SE 14th St
# 189106  Casey's General Store #2874 / Riceville          208 W Main St
#
#                    City Zip Code                Store Location County Number  \
# 169624  Windsor Heights    50324  POINT (-93.722436 41.614669)            77
# 169625     Cedar Rapids    52411  POINT (-91.701581 42.030129)            57
# 181634        Lake View    51450  POINT (-95.051532 42.307787)            81
# 181671       Des Moines    50320  POINT (-93.596756 41.553941)            77
# 181727       Des Moines    50315  POINT (-93.602514 41.526291)            77
# ...                 ...      ...                           ...           ...
# 181528     Cedar Rapids    52405  POINT (-91.680323 41.977958)            57
# 169694        Davenport    52804                           NaN            82
# 169696  West Des Moines    50266  POINT (-93.779582 41.559274)            77
# 169670       Des Moines    50320  POINT (-93.596756 41.553941)            77
# 189106        Riceville    50466   POINT (-92.55645 43.363838)            45
#
#         County Category                 Category Name Vendor Number  \
# 169624    Polk  1012300            Single Malt Scotch           260
# 169625    LINN  1011600         Straight Rye Whiskies           260
# 181634     SAC  1032200       Imported Flavored Vodka           370
# 181671    POLK  1082000  Imported Cordials & Liqueurs           192
# 181727    POLK  1022200            100% Agave Tequila           192
# ...        ...      ...                           ...           ...
# 181528    LINN  1081600               Whiskey Liqueur           421
# 169694   SCOTT  1011100              Blended Whiskies           260
# 169696    POLK  1011200     Straight Bourbon Whiskies           065
# 169670    POLK  1081600               Whiskey Liqueur           421
# 189106  HOWARD  1031100               American Vodkas           626
#
#                            Vendor Name Item Number  \
# 169624                 DIAGEO AMERICAS      905426
# 169625                 DIAGEO AMERICAS       27026
# 181634               PERNOD RICARD USA       34051
# 181671       Mast-Jagermeister US, Inc       65257
# 181727       Mast-Jagermeister US, Inc       88371
# ...                                ...         ...
# 181528            SAZERAC COMPANY  INC      100413
# 169694                 DIAGEO AMERICAS       25608
# 169696                 Jim Beam Brands       16685
# 169670            SAZERAC COMPANY  INC       67267
# 189106  JDSO INC / Red Boot Distillery       36873
#
#                               Item Description  Pack  Bottle Volume (ml)  \
# 169624         HA Lagavulin Distillers Edition     6                 750
# 169625                          Bulleit 95 Rye    12                1000
# 181634                       Absolut Raspberri    12                1000
# 181671                    Jagermeister Liqueur    12                1000
# 181727                 Teremana Blanco Tequila     6                 750
# ...                                        ...   ...                 ...
# 181528  Fireball Cinnamon Whiskey Party Bucket     1                  50
# 169694                        Seagrams 7 Crown     6                1750
# 169696                      Basil Hayden Toast     6                 750
# 169670                              Yukon Jack    12                1000
# 189106                           Blue Ox Vodka    12                 750
#
#         State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 169624              59.99                89.99             1           89.99
# 169625              20.49                30.74             3           92.22
# 181634              14.99                22.49            12          269.88
# 181671              16.50                24.75            96         2376.00
# 181727              14.94                22.41             6          134.46
# ...                   ...                  ...           ...             ...
# 181528              51.60                77.40             1           77.40
# 169694              12.96                19.44             6          116.64
# 169696              25.00                37.50             6          225.00
# 169670              11.75                17.63            12          211.56
# 189106               3.41                 5.12            12           61.44
#
#         Volume Sold (Liters)  Volume Sold (Gallons)    dd_date  volume
# 169624                  0.75                   0.19 2022-02-28    0.75
# 169625                  3.00                   0.79 2022-02-28    1.00
# 181634                 12.00                   3.17 2022-02-28    1.00
# 181671                 96.00                  25.36 2022-02-28    1.00
# 181727                  4.50                   1.18 2022-02-28    0.75
# ...                      ...                    ...        ...     ...
# 181528                  0.05                   0.01 2022-02-28    0.05
# 169694                 10.50                   2.77 2022-02-28    1.75
# 169696                  4.50                   1.18 2022-02-28    0.75
# 169670                 12.00                   3.17 2022-02-28    1.00
# 189106                  9.00                   2.37 2022-02-28    0.75
#
# [100 rows x 26 columns]

# %% [markdown]
# toy test

# %%
df = pd.DataFrame({'item_no': [1,1,1,1,2,2,2,2], 'descr': ['A','B','C','D','E','F','G','H'], 
                   'date_str': ['1/20/2022','1/30/2022','2/1/2022','2/28/2022','1/5/2022','1/21/2022','2/2/2022','1/3/2022']})
print(df)
# Out:
#    item_no descr   date_str
# 0        1     A  1/20/2022
# 1        1     B  1/30/2022
# 2        1     C   2/1/2022
# 3        1     D  2/28/2022
# 4        2     E   1/5/2022
# 5        2     F  1/21/2022
# 6        2     G   2/2/2022
# 7        2     H   1/3/2022

# %%
df['date'] = pd.to_datetime(df['date_str'])

# %%
df
# Out:
#    item_no descr   date_str       date
# 0        1     A  1/20/2022 2022-01-20
# 1        1     B  1/30/2022 2022-01-30
# 2        1     C   2/1/2022 2022-02-01
# 3        1     D  2/28/2022 2022-02-28
# 4        2     E   1/5/2022 2022-01-05
# 5        2     F  1/21/2022 2022-01-21
# 6        2     G   2/2/2022 2022-02-02
# 7        2     H   1/3/2022 2022-01-03

# %%
df.sort_values(by=['date']).drop_duplicates(['item_no'],keep='last')
# Out:
#    item_no descr   date_str       date
# 6        2     G   2/2/2022 2022-02-02
# 3        1     D  2/28/2022 2022-02-28
