# %%
import pandas as pd
import numpy as np

# %%
dp03 = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\census data\ACSDP5Y2020.DP03-2022-03-21T214613.csv')

# %%
cols = list(dp03.columns)

# %%
new_cols = list(filter(lambda col: "Estimate" in col,cols)) 

new_cols = ['Label (Grouping)'] + new_cols
new_cols
# Out:
# ['Label (Grouping)',
#  'ZCTA5 50001!!Estimate',
#  'ZCTA5 50002!!Estimate',
#  'ZCTA5 50003!!Estimate',
#  'ZCTA5 50005!!Estimate',
#  'ZCTA5 50006!!Estimate',
#  'ZCTA5 50007!!Estimate',
#  'ZCTA5 50008!!Estimate',
#  'ZCTA5 50009!!Estimate',
#  'ZCTA5 50010!!Estimate',
#  'ZCTA5 50011!!Estimate',
#  'ZCTA5 50012!!Estimate',
#  'ZCTA5 50014!!Estimate',
#  'ZCTA5 50020!!Estimate',
#  'ZCTA5 50021!!Estimate',
#  'ZCTA5 50022!!Estimate',
#  'ZCTA5 50023!!Estimate',
#  'ZCTA5 50025!!Estimate',
#  'ZCTA5 50026!!Estimate',
#  'ZCTA5 50027!!Estimate',
#  'ZCTA5 50028!!Estimate',
#  'ZCTA5 50029!!Estimate',
#  'ZCTA5 50032!!Estimate',
#  'ZCTA5 50033!!Estimate',
#  'ZCTA5 50034!!Estimate',
#  'ZCTA5 50035!!Estimate',
#  'ZCTA5 50036!!Estimate',
#  'ZCTA5 50038!!Estimate',
#  'ZCTA5 50039!!Estimate',
#  'ZCTA5 50041!!Estimate',
#  'ZCTA5 50042!!Estimate',
#  'ZCTA5 50044!!Estimate',
#  'ZCTA5 50046!!Estimate',
#  'ZCTA5 50047!!Estimate',
#  'ZCTA5 50048!!Estimate',
# ...

# %%
dp03_new = dp03[new_cols]
dp03_new
# Out:
#                                     Label (Grouping) ZCTA5 50001!!Estimate  \
# 0                                  EMPLOYMENT STATUS                   NaN
# 1                       Population 16 years and over                   544
# 2                                     In labor force                   385
# 3                               Civilian labor force                   385
# 4                                           Employed                   357
# ..                                               ...                   ...
# 140                                18 years and over                   (X)
# 141                                   18 to 64 years                   (X)
# 142                                65 years and over                   (X)
# 143                               People in families                   (X)
# 144          Unrelated individuals 15 years and over                   (X)
#
# ...

# %%
pd.set_option('display.max_rows', 146)
dp03_new.head(146)
# Out:
#                                       Label (Grouping) ZCTA5 50001!!Estimate  \
# 0                                    EMPLOYMENT STATUS                   NaN
# 1                         Population 16 years and over                   544
# 2                                       In labor force                   385
# 3                                 Civilian labor force                   385
# 4                                             Employed                   357
# 5                                           Unemployed                    28
# 6                                         Armed Forces                     0
# 7                                   Not in labor force                   159
# 8                                 Civilian labor force                   385
# 9                                    Unemployment Rate                   (X)
# 10                           Females 16 years and over                   276
# ...

# %%
dp03_new = dp03_new.drop(range(0,27))

# %%
dp03_new = dp03_new.reset_index()

# %%
 dp03_new = dp03_new.drop(range(7,28))

# %%
dp03_new = dp03_new.reset_index()

# %%
dp03_new = dp03_new.drop(range(20,97))

# %%
pd.set_option('display.max_rows', 20)
# dp03_new.head(20)

# %%
dp03_new = dp03_new.drop(['level_0', 'index'],axis=1)

# %%
dp03_new
# Out:
#                                      Label (Grouping) ZCTA5 50001!!Estimate  \
# 0                                          OCCUPATION                   NaN
# 1       Civilian employed population 16 years and ...                   357
# 2           Management, business, science, and art...                   207
# 3                                 Service occupations                    24
# 4                        Sales and office occupations                    64
# 5           Natural resources, construction, and m...                    20
# 6           Production, transportation, and materi...                    42
# 7   INCOME AND BENEFITS (IN 2020 INFLATION-ADJUSTE...                   NaN
# 8                                    Total households                   266
# 9                                   Less than $10,000                     0
# 10                                 $10,000 to $14,999                    29
# ...

# %%
def get_zip(string):
    L = string.split()
    L2 = L[1]
    L3 = L2.split('!!')
    zip = L3[0]
    return(zip)

# %%
cols = list(dp03_new.columns)
cols
# Out:
# ['Label (Grouping)',
#  'ZCTA5 50001!!Estimate',
#  'ZCTA5 50002!!Estimate',
#  'ZCTA5 50003!!Estimate',
#  'ZCTA5 50005!!Estimate',
#  'ZCTA5 50006!!Estimate',
#  'ZCTA5 50007!!Estimate',
#  'ZCTA5 50008!!Estimate',
#  'ZCTA5 50009!!Estimate',
#  'ZCTA5 50010!!Estimate',
#  'ZCTA5 50011!!Estimate',
#  'ZCTA5 50012!!Estimate',
#  'ZCTA5 50014!!Estimate',
#  'ZCTA5 50020!!Estimate',
#  'ZCTA5 50021!!Estimate',
#  'ZCTA5 50022!!Estimate',
#  'ZCTA5 50023!!Estimate',
#  'ZCTA5 50025!!Estimate',
#  'ZCTA5 50026!!Estimate',
#  'ZCTA5 50027!!Estimate',
#  'ZCTA5 50028!!Estimate',
#  'ZCTA5 50029!!Estimate',
#  'ZCTA5 50032!!Estimate',
#  'ZCTA5 50033!!Estimate',
#  'ZCTA5 50034!!Estimate',
#  'ZCTA5 50035!!Estimate',
#  'ZCTA5 50036!!Estimate',
#  'ZCTA5 50038!!Estimate',
#  'ZCTA5 50039!!Estimate',
#  'ZCTA5 50041!!Estimate',
#  'ZCTA5 50042!!Estimate',
#  'ZCTA5 50044!!Estimate',
#  'ZCTA5 50046!!Estimate',
#  'ZCTA5 50047!!Estimate',
#  'ZCTA5 50048!!Estimate',
# ...

# %%
new_cols = ['Label' if 'Label' in col_name   else get_zip(col_name) for col_name in cols]

# %%
new_cols
# Out:
# ['Label',
#  '50001',
#  '50002',
#  '50003',
#  '50005',
#  '50006',
#  '50007',
#  '50008',
#  '50009',
#  '50010',
#  '50011',
#  '50012',
#  '50014',
#  '50020',
#  '50021',
#  '50022',
#  '50023',
#  '50025',
#  '50026',
#  '50027',
#  '50028',
#  '50029',
#  '50032',
#  '50033',
#  '50034',
#  '50035',
#  '50036',
#  '50038',
#  '50039',
#  '50041',
#  '50042',
#  '50044',
#  '50046',
#  '50047',
#  '50048',
#  '50049',
#  '50050',
#  '50051',
#  '50052',
#  '50054',
#  '50055',
#  '50056',
#  '50057',
#  '50058',
#  '50060',
#  '50061',
#  '50062',
#  '50063',
#  '50064',
#  '50065',
#  '50066',
#  '50067',
#  '50068',
#  '50069',
#  '50070',
#  '50071',
#  '50072',
#  '50073',
#  '50074',
#  '50075',
#  '50076',
#  '50078',
#  '50101',
#  '50102',
#  '50103',
#  '50104',
#  '50105',
#  '50106',
#  '50107',
#  '50108',
#  '50109',
#  '50111',
#  '50112',
#  '50115',
#  '50116',
#  '50117',
#  '50118',
#  '50119',
#  '50120',
#  '50122',
#  '50123',
#  '50124',
#  '50125',
# ...

# %%
dp03_new.columns = new_cols

# %%
dp03_new= dp03_new.set_index('Label').T

# %%
dp03_new
# Out:
# Label OCCUPATION     Civilian employed population 16 years and over  \
# 50001        NaN                                                357
# 50002        NaN                                                724
# 50003        NaN                                              4,232
# 50005        NaN                                                474
# 50006        NaN                                                859
# ...          ...                                                ...
# 52803        NaN                                             11,067
# 52804        NaN                                             13,892
# 52806        NaN                                             13,154
# 52807        NaN                                              7,952
# 56027        NaN                                                325
#
# Label         Management, business, science, and arts occupations  \
# 50001                                                207
# ...

# %%
dp03_new.columns = dp03_new.columns.str.replace(' ','_')

# %%
dp03_new
# Out:
# Label OCCUPATION     Civilian_employed_population_16_years_and_over  \
# 50001        NaN                                                357
# 50002        NaN                                                724
# 50003        NaN                                              4,232
# 50005        NaN                                                474
# 50006        NaN                                                859
# ...          ...                                                ...
# 52803        NaN                                             11,067
# 52804        NaN                                             13,892
# 52806        NaN                                             13,154
# 52807        NaN                                              7,952
# 56027        NaN                                                325
#
# Label         Management,_business,_science,_and_arts_occupations  \
# 50001                                                207
# ...
