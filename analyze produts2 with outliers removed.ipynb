# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dict_dtype = {'Item_Number':str,
'Bottle_Volume (ml)':int,
'Bottles_Sold':int,
'Bottle_Retail':float,
'Store_Number':int}

# %%
products2 = pd.read_csv(r'C:\Users\dgarb\OneDrive\Desktop\Capstone Data\liquor_2021\products2_outliers_removed.csv',dtype=dict_dtype, index_col=0)

# %%
products2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4468 entries, 1 to 4474
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Number           4468 non-null   object
#  1   Item_Description      4468 non-null   object
#  2   Bottle_Volume         4468 non-null   int64
#  3   New_Category_Name     4468 non-null   object
#  4   Bottle_Retail         4468 non-null   float64
#  5   Bottles_Sold          4468 non-null   int32
#  6   Num_Stores_Selling    4468 non-null   int64
#  7   revenue               4468 non-null   float64
#  8   Bottle_Volume_scaled  4468 non-null   float64
#  9   Bottle_Retail_scaled  4468 non-null   float64
#  10  Bottles_Sold_scaled   4468 non-null   float64
#  11  product_cluster       4468 non-null   int64
#  12  Bottle_Volume_liters  4468 non-null   float64
#  13  cluster_name          4468 non-null   object
#  14  price_per_ml          4468 non-null   float64
# ...

# %%
# products2['price_per_ml'] = products2['Bottle_Retail'] / products2['Bottle_Volume']

# %%
analyze_df =products2[['Item_Number','Item_Description','Bottle_Volume','Bottle_Retail','Bottle_Volume_liters','price_per_ml']]

# %%
analyze_df2  = analyze_df.loc[products2['Bottle_Volume'] < 750,:]

# %%
analyze_df2['Bottle_Retail'].median()
# Out:
# 9.0

# %%
analyze_df2['Bottle_Retail'].mean()
# Out:
# 17.551946808828752

# %%
gph = sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(analyze_df2['Bottle_Retail'], bins=150)
# Out:
# <AxesSubplot:xlabel='Bottle_Retail', ylabel='Count'>

# %%
gph = sns.set(rc = {'figure.figsize':(15,8)})
gfg = sns.scatterplot(data=analyze_df2, x='Bottle_Retail', y='Bottle_Volume')
plt.show()

# %%
analyze_df2['Bottle_Retail'].describe()
# Out:
# count    668.000000
# mean      17.551947
# std       24.991682
# min        0.990000
# 25%        6.432500
# 50%        9.000000
# 75%       17.002500
# max      215.730000
# Name: Bottle_Retail, dtype: float64

# %%
analyze_df2.loc[analyze_df2['Bottle_Retail'] > 50,:]
# Out:
#      Item_Number                                   Item_Description  \
# 13        100413             Fireball Cinnamon Whiskey Party Bucket
# 42        100847              Fireball Cinnamon Whiskey Candy Canes
# 44        100855                   Makers Mark Generations Tri-Pack
# 46        100861                              99 Party Bucket Minis
# 47        100862                               99 Brand Candy Canes
# 74        101151  Fireball Cinnamon Whiskey Adult Trick Or Treat...
# 80        101182                Johnnie Walker 12 days of Discovery
# 98        101296                       WhistlePig 6YR PiggyBack Rye
# 126       101472           99 Brand Adult Variety Trick & Treat Bag
# 127       101473              99 Brand Variety Party Yard Pack Mini
# 146       101575                Dr. McGillicuddys Candy Canes Minis
# 274        15178                               WhistlePig 10YR Mini
# 277        15181                               WhistlePig 10YR Mini
# ...

# %%
analyze_df2.loc[analyze_df2['Bottle_Retail'] > 50,:].shape
# Out:
# (45, 6)

# %%
analyze_df2.loc[(analyze_df2['Bottle_Retail'] < 50) & (analyze_df2['Bottle_Retail'] > 25),:]
# Out:
#      Item_Number                       Item_Description  Bottle_Volume  \
# 19        100568                           Bourbon Time            375
# 23        100612     Johnnie Walker Mini Discovery Pack             50
# 34        100759          Jim Beam Holiday 4 Pack Minis            200
# 35        100771           Platinum 7x Vodka Candy Cane             50
# 62        101049               FLAVORED RUMS MULTI PACK             50
# ...          ...                                    ...            ...
# 4207      987281                  Casamigos Blanco Mini             50
# 4294      988829                Casamigos Reposado Mini             50
# 4295      988831                   Casamigos Anejo Mini             50
# 4456      999911               HA Wine-Finished Bourbon            375
# 4474      999993  Kings County Distillery Wheat Whiskey            375
#
#       Bottle_Retail  Bottle_Volume_liters  price_per_ml
# 19        33.000000                 0.375      0.088000
# ...

# %%
analyze_df2.loc[(analyze_df2['Bottle_Retail'] < 50) & (analyze_df2['Bottle_Retail'] > 25),:].shape
# Out:
# (67, 6)
